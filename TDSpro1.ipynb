# %%
import requests
import csv
import time
import os

GITHUB_TOKEN = "token"
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

def get_rate_limit():
    response = requests.get("https://api.github.com/rate_limit", headers=HEADERS, timeout=10)
    rate_limit_info = response.json()
    remaining_requests = rate_limit_info['rate']['remaining']
    reset_time = rate_limit_info['rate']['reset']
    print(f"Remaining requests: {remaining_requests}")
    print(f"Rate limit resets at: {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(reset_time))}")

def get_users_in_city(city="Toronto", min_followers=100):
    users = []
    query = f"location:{city}+followers:>{min_followers}"
    page = 1
    per_page = 100
    total_users = 0

    while True:
        url = f"https://api.github.com/search/users?q={query}&per_page={per_page}&page={page}"

        # Check the rate limit before making a request
        get_rate_limit()

        response = requests.get(url, headers=HEADERS, timeout=10)
        print(f"Fetching page {page}...")

        if response.status_code != 200:
            print("Error fetching data:", response.json())
            break

        data = response.json()
        users.extend(data['items'])
        total_users += len(data['items'])

        # Debug: print the total number of users fetched so far
        print(f"Total users fetched so far: {total_users}")

        if len(data['items']) < per_page:
            break

        page += 1
        time.sleep(2)  # Rate limiting - increased delay

    detailed_users = [get_user_details(user['login']) for user in users]
    return detailed_users

def get_user_details(username):
    print(f"Fetching details for user: {username}")
    user_url = f"https://api.github.com/users/{username}"
    try:
        user_data = requests.get(user_url, headers=HEADERS, timeout=10).json()
    except requests.exceptions.Timeout:
        print(f"Timeout occurred while fetching user details for {username}")
        return {}

    return {
        'login': user_data.get('login', ''),
        'name': user_data.get('name', ''),
        'company': clean_company_name(user_data.get('company')),
        'location': user_data.get('location', ''),
        'email': user_data.get('email', ''),
        'hireable': user_data.get('hireable', ''),
        'bio': user_data.get('bio', ''),
        'public_repos': user_data.get('public_repos', 0),
        'followers': user_data.get('followers', 0),
        'following': user_data.get('following', 0),
        'created_at': user_data.get('created_at', ''),
    }

def clean_company_name(company):
    if company:
        company = company.strip().upper()
        if company.startswith('@'):
            company = company[1:]
    return company or ""

def get_user_repos(username):
    print(f"Fetching repositories for user: {username}")
    repos = []
    page = 1
    per_page = 100
    while True:
        repos_url = f"https://api.github.com/users/{username}/repos?per_page={per_page}&page={page}"
        try:
            response = requests.get(repos_url, headers=HEADERS, timeout=10)
        except requests.exceptions.Timeout:
            print(f"Timeout occurred while fetching repos for user: {username}")
            break

        if response.status_code != 200:
            print("Error fetching repos for user:", username)
            break

        repos_data = response.json()
        if not repos_data:
            break

        for repo in repos_data:
            repos.append({
                'login': username,
                'full_name': repo['full_name'],
                'created_at': repo['created_at'],
                'stargazers_count': repo['stargazers_count'],
                'watchers_count': repo['watchers_count'],
                'language': repo.get('language', ''),
                'has_projects': repo.get('has_projects', False),
                'has_wiki': repo.get('has_wiki', False),
                'license_name': repo['license']['key'] if repo.get('license') else '',
            })

        page += 1
        time.sleep(2)  # Rate limiting - increased delay

    return repos

def save_to_csv(data, filename, fieldnames):
    os.makedirs("output", exist_ok=True)
    filepath = os.path.join("output", filename)
    with open(filepath, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(data)

if __name__ == "__main__":
    users = get_users_in_city("Toronto", 100)
    save_to_csv(users, 'users.csv', [
        'login', 'name', 'company', 'location', 'email', 'hireable', 'bio',
        'public_repos', 'followers', 'following', 'created_at'
    ])

    all_repos = []
    for user in users:
        repos = get_user_repos(user['login'])
        all_repos.extend(repos)

    save_to_csv(all_repos, 'repositories.csv', [
        'login', 'full_name', 'created_at', 'stargazers_count', 'watchers_count',
        'language', 'has_projects', 'has_wiki', 'license_name'
    ])
    print("Data saved successfully!")
# Out:
# Remaining requests: 2491
# Rate limit resets at: 2024-10-28 16:21:02
# Fetching page 1...
# Total users fetched so far: 100
# Remaining requests: 2491
# Rate limit resets at: 2024-10-28 16:21:02
# Fetching page 2...
# Total users fetched so far: 200
# Remaining requests: 2491
# Rate limit resets at: 2024-10-28 16:21:02
# Fetching page 3...
# Total users fetched so far: 300
# Remaining requests: 2491
# Rate limit resets at: 2024-10-28 16:21:02
# Fetching page 4...
# Total users fetched so far: 400
# Remaining requests: 2491
# Rate limit resets at: 2024-10-28 16:21:02
# Fetching page 5...
# Total users fetched so far: 500
# Remaining requests: 2491
# Rate limit resets at: 2024-10-28 16:21:02
# Fetching page 6...
# Total users fetched so far: 600
# Remaining requests: 2491
# Rate limit resets at: 2024-10-28 16:21:02
# Fetching page 7...
# Total users fetched so far: 685
# Fetching details for user: aneagoie
# Fetching details for user: ZhangMYihua
# Fetching details for user: susanli2016
# Fetching details for user: thedaviddias
# Fetching details for user: ange-yaghi
# Fetching details for user: nayuki
# Fetching details for user: stemmlerjs
# Fetching details for user: GrapheneOS
# Fetching details for user: MylesBorins
# Fetching details for user: vsavkin
# Fetching details for user: kevinjycui
# Fetching details for user: hlissner
# Fetching details for user: gazijarin
# Fetching details for user: priya-dwivedi
# Fetching details for user: dmitshur
# Fetching details for user: rspivak
# Fetching details for user: daattali
# Fetching details for user: chenyuntc
# Fetching details for user: jmorganca
# Fetching details for user: petertodd
# Fetching details for user: vladikoff
# Fetching details for user: michaelklishin
# Fetching details for user: raganwald
# Fetching details for user: dsherret
# Fetching details for user: codereport
# Fetching details for user: darcyclarke
# Fetching details for user: adam-p
# Fetching details for user: richlander
# Fetching details for user: rich-iannone
# Fetching details for user: ricmoo
# Fetching details for user: TarrySingh
# Fetching details for user: 1Password
# Fetching details for user: ehoneahobed
# Fetching details for user: craffel
# Fetching details for user: wiseodd
# Fetching details for user: markstory
# Fetching details for user: JasonEtco
# Fetching details for user: jtemporal
# Fetching details for user: alecjacobson
# Fetching details for user: Gaohaoyang
# Fetching details for user: shazow
# Fetching details for user: leighhalliday
# Fetching details for user: winkerVSbecks
# Fetching details for user: luisguiserrano
# Fetching details for user: sachac
# Fetching details for user: ziishaned
# Fetching details for user: abbycabs
# Fetching details for user: yogthos
# Fetching details for user: JunMa11
# Fetching details for user: caitp
# Fetching details for user: k88hudson
# Fetching details for user: gvwilson
# Fetching details for user: enderh3art
# Fetching details for user: ninjamuffin99
# Fetching details for user: Rishit-dagli
# Fetching details for user: BenEmdon
# Fetching details for user: hejazizo
# Fetching details for user: aritchie
# Fetching details for user: jgrandja
# Fetching details for user: lazerwalker
# Fetching details for user: xinshuoweng
# Fetching details for user: pkieltyka
# Fetching details for user: iceburgcrm
# Fetching details for user: iH8sn0w
# Fetching details for user: ahmadnassri
# Fetching details for user: zackradisic
# Fetching details for user: ChainSafe
# Fetching details for user: OlivierLaflamme
# Fetching details for user: lstein
# Fetching details for user: jaysoo
# Fetching details for user: benvinegar
# Fetching details for user: davidrosenberg
# Fetching details for user: Idnan
# Fetching details for user: rokon12
# Fetching details for user: eviltrout
# Fetching details for user: vipulasri
# Fetching details for user: jamesagnew
# Fetching details for user: spencermountain
# Fetching details for user: vito
# Fetching details for user: HamedBahram
# Fetching details for user: olado
# Fetching details for user: ibraheemdev
# Fetching details for user: steveseguin
# Fetching details for user: fantix
# Fetching details for user: gf3
# Fetching details for user: GunterMueller
# Fetching details for user: FaisalAbid
# Fetching details for user: mhammond
# Fetching details for user: glouw
# Fetching details for user: odziem
# Fetching details for user: cenkalti
# Fetching details for user: anniebombanie
# Fetching details for user: Windscribe
# Fetching details for user: scrumtuous
# Fetching details for user: jsoref
# Fetching details for user: nikolovlazar
# Fetching details for user: mobinni
# Fetching details for user: kulkarniankita
# Fetching details for user: ploopyco
# Fetching details for user: DylanVann
# Fetching details for user: dnephin
# Fetching details for user: code-shoily
# Fetching details for user: abetlen
# Fetching details for user: tsiliopoulos
# Fetching details for user: josh0xA
# Fetching details for user: barry-far
# Fetching details for user: npapernot
# Fetching details for user: kamiyaa
# Fetching details for user: OmarElgabry
# Fetching details for user: sideeffects
# Fetching details for user: AtotheY
# Fetching details for user: r-park
# Fetching details for user: tristanhimmelman
# Fetching details for user: rgrinberg
# Fetching details for user: jaberg
# Fetching details for user: Wuziyi616
# Fetching details for user: etimberg
# Fetching details for user: ExamProCo
# Fetching details for user: GeorgeSeif
# Fetching details for user: wolever
# Fetching details for user: st3fan
# Fetching details for user: DaleSeo
# Fetching details for user: martindurant
# Fetching details for user: swalkinshaw
# Fetching details for user: jts
# Fetching details for user: heybereket
# Fetching details for user: ImranR98
# Fetching details for user: san089
# Fetching details for user: WolfgangOfner
# Fetching details for user: davellanedam
# Fetching details for user: shayanb
# Fetching details for user: piyush97
# Fetching details for user: fmfn
# Fetching details for user: ReikaKalseki
# Fetching details for user: antonitz
# Fetching details for user: itsdevbear
# Fetching details for user: phuc-mai
# Fetching details for user: maxhumber
# Fetching details for user: mszoek
# Fetching details for user: JacintoDesign
# Fetching details for user: djirdehh
# Fetching details for user: cnbeining
# Fetching details for user: aarnphm
# Fetching details for user: fardad
# Fetching details for user: n1ckfg
# Fetching details for user: cheezy
# Fetching details for user: chmln
# Fetching details for user: jobovy
# Fetching details for user: filippbudko
# Fetching details for user: henrytao-me
# Fetching details for user: michaelshimeles
# Fetching details for user: bruno-garcia
# Fetching details for user: fwang
# Fetching details for user: tomhodgins
# Fetching details for user: alicoding
# Fetching details for user: Devang-25
# Fetching details for user: deniseyu
# Fetching details for user: lextm
# Fetching details for user: t-mullen
# Fetching details for user: Tabrizian
# Fetching details for user: mystor
# Fetching details for user: una-dinosauria
# Fetching details for user: davepagurek
# Fetching details for user: indy256
# Fetching details for user: ethers-io
# Fetching details for user: xjasonlyu
# Fetching details for user: bioinformatics-ca
# Fetching details for user: kobiso
# Fetching details for user: RetroNick2020
# Fetching details for user: pycaret
# Fetching details for user: bowang-lab
# Fetching details for user: chesterbr
# Fetching details for user: laion01
# Fetching details for user: vasanthv
# Fetching details for user: shyndman
# Fetching details for user: xiaozhouwang
# Fetching details for user: pilwon
# Fetching details for user: moezbhatti
# Fetching details for user: iamnbutler
# Fetching details for user: danieldjohnson
# Fetching details for user: patcon
# Fetching details for user: alamkanak
# Fetching details for user: HackerYou
# Fetching details for user: tristen
# Fetching details for user: ryanshrott
# Fetching details for user: jneen
# Fetching details for user: Tech-With-Tim
# Fetching details for user: FrozenPandaz
# Fetching details for user: XanaduAI
# Fetching details for user: zoltan-nz
# Fetching details for user: BlakeBrown
# Fetching details for user: codewithchris
# Fetching details for user: alex-okrushko
# Fetching details for user: kelvinxu
# Fetching details for user: mahedee
# Fetching details for user: hannorein
# Fetching details for user: colinta
# Fetching details for user: alexminnaar
# Fetching details for user: jaseva
# Fetching details for user: syavash
# Fetching details for user: atesgoral
# Fetching details for user: andrewn6
# Fetching details for user: rileyjshaw
# Fetching details for user: sgbaird
# Fetching details for user: brenna
# Fetching details for user: joykare
# Fetching details for user: fmoliveira
# Fetching details for user: devinpleuler
# Fetching details for user: pritamworld
# Fetching details for user: vnmakarov
# Fetching details for user: websanova
# Fetching details for user: ritheshkumar95
# Fetching details for user: friyiajr
# Fetching details for user: dalenguyen
# Fetching details for user: makew0rld
# Fetching details for user: david-gpu
# Fetching details for user: amsul
# Fetching details for user: SteveJunGao
# Fetching details for user: VectorInstitute
# Fetching details for user: WilsonWangTHU
# Fetching details for user: mtrudel
# Fetching details for user: NickQiZhu
# Fetching details for user: Christopher2K
# Fetching details for user: for-ai
# Fetching details for user: JessicaLim8
# Fetching details for user: impressivewebs
# Fetching details for user: josh146
# Fetching details for user: mrisdal
# Fetching details for user: mstechly
# Fetching details for user: iSimar
# Fetching details for user: watadarkstar
# Fetching details for user: LuaxY
# Fetching details for user: danialfarid
# Fetching details for user: msantos
# Fetching details for user: brianpeiris
# Fetching details for user: jteneycke
# Fetching details for user: taras
# Fetching details for user: kinngh
# Fetching details for user: cpt-waffle
# Fetching details for user: thomas-lowry
# Fetching details for user: plentz
# Fetching details for user: ddavison
# Fetching details for user: Rayhane-mamah
# Fetching details for user: leebenson
# Fetching details for user: rgeirhos
# Fetching details for user: stevemar
# Fetching details for user: iKevinY
# Fetching details for user: arjungautam1
# Fetching details for user: filmaj
# Fetching details for user: MrGemy95
# Fetching details for user: MagicStack
# Fetching details for user: ElliotKillick
# Fetching details for user: thephoeron
# Fetching details for user: akshitac8
# Fetching details for user: interactiveimmersivehq
# Fetching details for user: theoomoregbee
# Fetching details for user: elbruno
# Fetching details for user: Hermanya
# Fetching details for user: janetacarr
# Fetching details for user: amacgregor
# Fetching details for user: kelvinlauKL
# Fetching details for user: chitwansaharia
# Fetching details for user: oalders
# Fetching details for user: Furkanzmc
# Fetching details for user: EverythingSuckz
# Fetching details for user: geographyclub
# Fetching details for user: therajanmaurya
# Fetching details for user: oliveiralecca
# Fetching details for user: QuLogic
# Fetching details for user: gizak
# Fetching details for user: epitron
# Fetching details for user: cameronmcnz
# Fetching details for user: mikkoh
# Fetching details for user: NoahDragon
# Fetching details for user: tomkralidis
# Fetching details for user: sebjai
# Fetching details for user: adryd325
# Fetching details for user: MJAlexander
# Fetching details for user: moezali1
# Fetching details for user: wohali
# Fetching details for user: mjangda
# Fetching details for user: DjDeveloperr
# Fetching details for user: JohnSully
# Fetching details for user: ericevenchick
# Fetching details for user: jess-data
# Fetching details for user: ReallySnow
# Fetching details for user: ylogx
# Fetching details for user: jeffrey-xiao
# Fetching details for user: marcospereira
# Fetching details for user: corbanbrook
# Fetching details for user: AutodeskAILab
# Fetching details for user: danqzq
# Fetching details for user: julianlam
# Fetching details for user: DateBro
# Fetching details for user: dashed
# Fetching details for user: keeferrourke
# Fetching details for user: aleemrehmtulla
# Fetching details for user: randyaajr
# Fetching details for user: Rchristiani
# Fetching details for user: moollaza
# Fetching details for user: jacobparis
# Fetching details for user: toksdotdev
# Fetching details for user: walkah
# Fetching details for user: erwanor
# Fetching details for user: ItsJonQ
# Fetching details for user: AndreiBarsan
# Fetching details for user: chocoluffy
# Fetching details for user: mfridman
# Fetching details for user: ruebot
# Fetching details for user: teamchong
# Fetching details for user: yawaramin
# Fetching details for user: fahdi
# Fetching details for user: teesloane
# Fetching details for user: truskovskiyk
# Fetching details for user: Continuities
# Fetching details for user: atgreen
# Fetching details for user: adriengivry
# Fetching details for user: hectris
# Fetching details for user: jules2689
# Fetching details for user: Sticktron
# Fetching details for user: pct960
# Fetching details for user: ehsan
# Fetching details for user: joshl26
# Fetching details for user: peterzhu2118
# Fetching details for user: arsduo
# Fetching details for user: prrao87
# Fetching details for user: kcnickerson
# Fetching details for user: TouchDesigner
# Fetching details for user: friendly
# Fetching details for user: knazeri
# Fetching details for user: andyw8
# Fetching details for user: seyonechithrananda
# Fetching details for user: ankonzoid
# Fetching details for user: markf94
# Fetching details for user: ansis
# Fetching details for user: bk2204
# Fetching details for user: alifa98
# Fetching details for user: m4mallu
# Fetching details for user: deluan
# Fetching details for user: hexonaut
# Fetching details for user: Danial-Kord
# Fetching details for user: joeyism
# Fetching details for user: HuguesTHOMAS
# Fetching details for user: spike01
# Fetching details for user: lacarmen
# Fetching details for user: yaoyaoding
# Fetching details for user: pushmatrix
# Fetching details for user: websemantics
# Fetching details for user: NorthernMan54
# Fetching details for user: SoroushMehraban
# Fetching details for user: ljdursi
# Fetching details for user: phillmv
# Fetching details for user: stevehu
# Fetching details for user: ChainSafeSystems
# Fetching details for user: tbabej
# Fetching details for user: ldct
# Fetching details for user: CNBorn
# Fetching details for user: DylanMeeus
# Fetching details for user: JohnGiorgi
# Fetching details for user: pschroen
# Fetching details for user: TroyKomodo
# Fetching details for user: HACKERALERT
# Fetching details for user: hammadshaikhha
# Fetching details for user: dilevin
# Fetching details for user: gregorycollins
# Fetching details for user: agile8118
# Fetching details for user: SandyLudosky
# Fetching details for user: bytenaija
# Fetching details for user: MatinTavakoli
# Fetching details for user: KingsMentor
# Fetching details for user: danielmoniz
# Fetching details for user: micdoodle8
# Fetching details for user: rishirdua
# Fetching details for user: hyfen
# Fetching details for user: topspinj
# Fetching details for user: jameskokoska
# Fetching details for user: lucas-manuel
# Fetching details for user: bredele
# Fetching details for user: tonybaltovski
# Fetching details for user: es
# Fetching details for user: flawnson
# Fetching details for user: svinkle
# Fetching details for user: brynnsmith
# Fetching details for user: rosszurowski
# Fetching details for user: nicholasaleks
# Fetching details for user: countcain
# Fetching details for user: upul
# Fetching details for user: kashav
# Fetching details for user: novatorem
# Fetching details for user: wealthsimple
# Fetching details for user: ShikharJ
# Fetching details for user: league1991
# Fetching details for user: suhaibaffan
# Fetching details for user: amlankar
# Fetching details for user: Xyene
# Fetching details for user: yashkant
# Fetching details for user: QuinntyneBrown
# Fetching details for user: lgfa29
# Fetching details for user: rafd
# Fetching details for user: caffeinum
# Fetching details for user: rafaelsteil
# Fetching details for user: RohanAlexander
# Fetching details for user: clouddrove
# Fetching details for user: utiasASRL
# Fetching details for user: mveytsman
# Fetching details for user: alex-wilmer
# Fetching details for user: colinbdclark
# Fetching details for user: cheapsteak
# Fetching details for user: MohamedSlah27
# Fetching details for user: nhat416
# Fetching details for user: ephread
# Fetching details for user: moaazsidat
# Fetching details for user: WirelessLife
# Fetching details for user: davedbase
# Fetching details for user: MrCheeze
# Fetching details for user: kpumuk
# Fetching details for user: Seanforfun
# Fetching details for user: JoshVarty
# Fetching details for user: richardwu
# Fetching details for user: 32teeth
# Fetching details for user: philchalmers
# Fetching details for user: pnitsch
# Fetching details for user: ahlashkari
# Fetching details for user: benhylau
# Fetching details for user: ahmdrefat
# Fetching details for user: mohamed-tayeh
# Fetching details for user: edmundnoble
# Fetching details for user: halostatue
# Fetching details for user: Xenomega
# Fetching details for user: 0xsauby
# Fetching details for user: jamesmacaulay
# Fetching details for user: JasonLovesDoggo
# Fetching details for user: asaikali
# Fetching details for user: ameliemaia
# Fetching details for user: invokethreatguy
# Fetching details for user: richgilbank
# Fetching details for user: Jeremboo
# Fetching details for user: AeroAndZero
# Fetching details for user: barisusakli
# Fetching details for user: marcelluscaio
# Fetching details for user: marcbensan
# Fetching details for user: 1Computer1
# Fetching details for user: xrenaa
# Fetching details for user: mssroboto
# Fetching details for user: distributethe6ix
# Fetching details for user: frank-liu-toronto
# Fetching details for user: quantum5
# Fetching details for user: bsormagec
# Fetching details for user: incizzle
# Fetching details for user: darcymason
# Fetching details for user: domluna
# Fetching details for user: andre-nguyen
# Fetching details for user: npow
# Fetching details for user: RaeesBhatti
# Fetching details for user: johnmal-dev
# Fetching details for user: tessus
# Fetching details for user: nathanmarks
# Fetching details for user: rafaelperez
# Fetching details for user: Abtinz
# Fetching details for user: manjitkumar
# Fetching details for user: jonathanlilly
# Fetching details for user: e-schultz
# Fetching details for user: itsflores
# Fetching details for user: CaydenPierce
# Fetching details for user: michaelstepner
# Fetching details for user: Abiodun-Shittu
# Fetching details for user: mikeboers
# Fetching details for user: Yifeng-He
# Fetching details for user: AtheMathmo
# Fetching details for user: gabrielgrant
# Fetching details for user: amanjeev
# Fetching details for user: dmitryrck
# Fetching details for user: danielsnider
# Fetching details for user: lsvekis
# Fetching details for user: jairojair
# Fetching details for user: marcgibbons
# Fetching details for user: daniellewebb-xx
# Fetching details for user: jbuck
# Fetching details for user: pangloss
# Fetching details for user: arieling
# Fetching details for user: carolinanonato
# Fetching details for user: johnantoni
# Fetching details for user: calvinlfer
# Fetching details for user: wgrathwohl
# Fetching details for user: psychobunny
# Fetching details for user: zazencodes
# Fetching details for user: baudehlo
# Fetching details for user: vodik
# Fetching details for user: rayryeng
# Fetching details for user: seglo
# Fetching details for user: william-tran
# Fetching details for user: zlovatt
# Fetching details for user: gaojunxuan
# Fetching details for user: nicholaschum
# Fetching details for user: Yumcoder-dev
# Fetching details for user: nicholas-tao
# Fetching details for user: joshspeagle
# Fetching details for user: crespire
# Fetching details for user: LucasBoTang
# Fetching details for user: ParsaMehdipour
# Fetching details for user: siebenmann
# Fetching details for user: Coldcard
# Fetching details for user: mikeconley
# Fetching details for user: jairajs89
# Fetching details for user: Shchvova
# Fetching details for user: rms80
# Fetching details for user: ArmanJR
# Fetching details for user: leibovic
# Fetching details for user: kintel
# Fetching details for user: bmarchete
# Fetching details for user: arkalim
# Fetching details for user: MichaelDiBernardo
# Fetching details for user: bwinton
# Fetching details for user: ahmadsalimi
# Fetching details for user: ueg1990
# Fetching details for user: jamaps
# Fetching details for user: fightingtheboss
# Fetching details for user: kracwarlock
# Fetching details for user: SteakEnthusiast
# Fetching details for user: myles
# Fetching details for user: ssydasheng
# Fetching details for user: Krutonium
# Fetching details for user: dvrzan
# Fetching details for user: Snivyn
# Fetching details for user: rajansagarwal
# Fetching details for user: BrityHemming
# Fetching details for user: aleccool213
# Fetching details for user: ikokkari
# Fetching details for user: akhomochkina
# Fetching details for user: ShayanDeSh
# Fetching details for user: takiszourntos
# Fetching details for user: chmodxx
# Fetching details for user: ababaian
# Fetching details for user: sedghi
# Fetching details for user: 1997alireza
# Fetching details for user: kieranrcampbell
# Fetching details for user: shinyorg
# Fetching details for user: jasongoodwin
# Fetching details for user: hhaidar
# Fetching details for user: tracymakes
# Fetching details for user: iBicha
# Fetching details for user: DillonN
# Fetching details for user: iancanada
# Fetching details for user: JohnOnSoftware
# Fetching details for user: wxs
# Fetching details for user: stephaniegiang
# Fetching details for user: dipikabh
# Fetching details for user: priom
# Fetching details for user: shonfeder
# Fetching details for user: yysun
# Fetching details for user: melaniesigrid
# Fetching details for user: Bortseb
# Fetching details for user: chyyran
# Fetching details for user: zoffixznet
# Fetching details for user: NS007-dev
# Fetching details for user: jrmuizel
# Fetching details for user: nickyiliwang
# Fetching details for user: supermacro
# Fetching details for user: farnoodma
# Fetching details for user: eltonvs
# Fetching details for user: rilian
# Fetching details for user: brvoigt
# Fetching details for user: Hardanish-Singh
# Fetching details for user: mstange
# Fetching details for user: adamfuhrer
# Fetching details for user: binyoon99
# Fetching details for user: rafkhan
# Fetching details for user: invisibleBully
# Fetching details for user: davifrossard
# Fetching details for user: blackHatMonkey
# Fetching details for user: thanethomson
# Fetching details for user: junzhengca
# Fetching details for user: AVAV2500
# Fetching details for user: rfratto
# Fetching details for user: nwjsmith
# Fetching details for user: shwina
# Fetching details for user: elliottsj
# Fetching details for user: NimaGhaedsharafi
# Fetching details for user: sumitarora
# Fetching details for user: seanpaultaylor
# Fetching details for user: probil
# Fetching details for user: bani
# Fetching details for user: liaojason2
# Fetching details for user: moein-shafi
# Fetching details for user: kyoshino
# Fetching details for user: scottclowe
# Fetching details for user: jinsley8
# Fetching details for user: caseware
# Fetching details for user: amangalvedhekar
# Fetching details for user: Prtfw
# Fetching details for user: haroldtreen
# Fetching details for user: liamks
# Fetching details for user: EmilyGraceSeville7cf
# Fetching details for user: Jerry1211
# Fetching details for user: ianmackenzie
# Fetching details for user: ppaquette
# Fetching details for user: kiosion
# Fetching details for user: rymcol
# Fetching details for user: quepol
# Fetching details for user: nlalonde
# Fetching details for user: jstaf
# Fetching details for user: NickStrupat
# Fetching details for user: nickpresta
# Fetching details for user: ChigboIO
# Fetching details for user: douglasmakey
# Fetching details for user: dgomesbr
# Fetching details for user: eadamceylan
# Fetching details for user: thejmazz
# Fetching details for user: michaelchi08
# Fetching details for user: jameskeane
# Fetching details for user: svanoort
# Fetching details for user: hannes-brt
# Fetching details for user: radioblahaj
# Fetching details for user: FabioBatSilva
# Fetching details for user: KooroshRH
# Fetching details for user: hrzafer
# Fetching details for user: sepehrasgarian
# Fetching details for user: prodseanb
# Fetching details for user: bgilham
# Fetching details for user: LeNPaul
# Fetching details for user: sauricat
# Fetching details for user: adamgoucher
# Fetching details for user: daniil
# Fetching details for user: ryanwilsonperkin
# Fetching details for user: aehlke
# Fetching details for user: stevenvachon
# Fetching details for user: matt-sd-watson
# Fetching details for user: MisterJimson
# Fetching details for user: cltrudeau
# Fetching details for user: goatandsheep
# Fetching details for user: uptoamir
# Fetching details for user: NodeBB
# Fetching details for user: spacejack
# Fetching details for user: gvarandas
# Fetching details for user: lunaroyster
# Fetching details for user: vikramkakkar
# Fetching details for user: destruc7i0n
# Fetching details for user: ranacseruet
# Fetching details for user: yusuf8ahmed
# Fetching details for user: yzgyyang
# Fetching details for user: WilliamPourmajidi
# Fetching details for user: SC4RECOIN
# Fetching details for user: gngdb
# Fetching details for user: samgermain
# Fetching details for user: adrian-miasik
# Fetching details for user: itaymishan
# Fetching details for user: UddamB
# Fetching details for user: jmcardon
# Fetching details for user: Shawn-Ogbomo
# Fetching details for user: gregr
# Fetching details for user: HaydenMeloche
# Fetching details for user: clarabatt
# Fetching details for user: yasith
# Fetching details for user: robocoder
# Fetching details for user: amingilani
# Fetching details for user: igilitschenski
# Fetching details for user: scoremedia
# Fetching details for user: awgeezrick
# Fetching details for user: AfzalivE
# Fetching details for user: zhangsu
# Fetching details for user: mabuyo
# Fetching details for user: mwarkentin
# Fetching details for user: rohithpudari
# Fetching details for user: HuakunShen
# Fetching details for user: mmonfared
# Fetching details for user: osis
# Fetching details for user: yangze0930
# Fetching details for user: aarongough
# Fetching details for user: npjd
# Fetching details for user: itsbilal
# Fetching details for user: sharon-yi
# Fetching details for user: dcooney
# Fetching details for user: PabloVallejo
# Fetching details for user: gmoledina
# Fetching details for user: mc256
# Fetching details for user: mlxd
# Fetching details for user: aravind-3105
# Fetching details for user: basil2style
# Fetching details for user: dellisd
# Fetching details for user: finiterank
# Fetching details for user: acode
# Fetching details for user: gorkem-cetin
# Fetching details for user: rwhogg
# Fetching details for user: andrewdamelio
# Fetching details for user: qasim
# Fetching repositories for user: aneagoie
# Fetching repositories for user: ZhangMYihua
# Fetching repositories for user: susanli2016
# Fetching repositories for user: thedaviddias
# Fetching repositories for user: ange-yaghi
# Fetching repositories for user: nayuki
# Fetching repositories for user: stemmlerjs
# Fetching repositories for user: GrapheneOS
# Fetching repositories for user: MylesBorins
# Fetching repositories for user: vsavkin
# Fetching repositories for user: kevinjycui
# Fetching repositories for user: hlissner
# Fetching repositories for user: gazijarin
# Fetching repositories for user: priya-dwivedi
# Fetching repositories for user: dmitshur
# Fetching repositories for user: rspivak
# Fetching repositories for user: daattali
# Fetching repositories for user: chenyuntc
# Fetching repositories for user: jmorganca
# Fetching repositories for user: petertodd
# Fetching repositories for user: vladikoff
# Fetching repositories for user: michaelklishin
# Fetching repositories for user: raganwald
# Fetching repositories for user: dsherret
# Fetching repositories for user: codereport
# Fetching repositories for user: darcyclarke
# Fetching repositories for user: adam-p
# Fetching repositories for user: richlander
# Fetching repositories for user: rich-iannone
# Fetching repositories for user: ricmoo
# Fetching repositories for user: TarrySingh
# Fetching repositories for user: 1Password
# Fetching repositories for user: ehoneahobed
# Fetching repositories for user: craffel
# Fetching repositories for user: wiseodd
# Fetching repositories for user: markstory
# Fetching repositories for user: JasonEtco
# Fetching repositories for user: jtemporal
# Fetching repositories for user: alecjacobson
# Fetching repositories for user: Gaohaoyang
# Fetching repositories for user: shazow
# Fetching repositories for user: leighhalliday
# Fetching repositories for user: winkerVSbecks
# Fetching repositories for user: luisguiserrano
# Fetching repositories for user: sachac
# Fetching repositories for user: ziishaned
# Fetching repositories for user: abbycabs
# Fetching repositories for user: yogthos
# Fetching repositories for user: JunMa11
# Fetching repositories for user: caitp
# Fetching repositories for user: k88hudson
# Fetching repositories for user: gvwilson
# Fetching repositories for user: enderh3art
# Fetching repositories for user: ninjamuffin99
# Fetching repositories for user: Rishit-dagli
# Fetching repositories for user: BenEmdon
# Fetching repositories for user: hejazizo
# Fetching repositories for user: aritchie
# Fetching repositories for user: jgrandja
# Fetching repositories for user: lazerwalker
# Fetching repositories for user: xinshuoweng
# Fetching repositories for user: pkieltyka
# Fetching repositories for user: iceburgcrm
# Fetching repositories for user: iH8sn0w
# Fetching repositories for user: ahmadnassri
# Fetching repositories for user: zackradisic
# Fetching repositories for user: ChainSafe
# Fetching repositories for user: OlivierLaflamme
# Fetching repositories for user: lstein
# Fetching repositories for user: jaysoo
# Fetching repositories for user: benvinegar
# Fetching repositories for user: davidrosenberg
# Fetching repositories for user: Idnan
# Fetching repositories for user: rokon12
# Fetching repositories for user: eviltrout
# Fetching repositories for user: vipulasri
# Fetching repositories for user: jamesagnew
# Fetching repositories for user: spencermountain
# Fetching repositories for user: vito
# Fetching repositories for user: HamedBahram
# Fetching repositories for user: olado
# Fetching repositories for user: ibraheemdev
# Fetching repositories for user: steveseguin
# Fetching repositories for user: fantix
# Fetching repositories for user: gf3
# Fetching repositories for user: GunterMueller
# Fetching repositories for user: FaisalAbid
# Fetching repositories for user: mhammond
# Fetching repositories for user: glouw
# Fetching repositories for user: odziem
# Fetching repositories for user: cenkalti
# Fetching repositories for user: anniebombanie
# Fetching repositories for user: Windscribe
# Fetching repositories for user: scrumtuous
# Fetching repositories for user: jsoref
# Fetching repositories for user: nikolovlazar
# Fetching repositories for user: mobinni
# Fetching repositories for user: kulkarniankita
# Fetching repositories for user: ploopyco
# Fetching repositories for user: DylanVann
# Fetching repositories for user: dnephin
# Fetching repositories for user: code-shoily
# Fetching repositories for user: abetlen
# Fetching repositories for user: tsiliopoulos
# Fetching repositories for user: josh0xA
# Fetching repositories for user: barry-far
# Fetching repositories for user: npapernot
# Fetching repositories for user: kamiyaa
# Fetching repositories for user: OmarElgabry
# Fetching repositories for user: sideeffects
# Fetching repositories for user: AtotheY
# Fetching repositories for user: r-park
# Fetching repositories for user: tristanhimmelman
# Fetching repositories for user: rgrinberg
# Fetching repositories for user: jaberg
# Fetching repositories for user: Wuziyi616
# Fetching repositories for user: etimberg
# Fetching repositories for user: ExamProCo
# Fetching repositories for user: GeorgeSeif
# Fetching repositories for user: wolever
# Fetching repositories for user: st3fan
# Fetching repositories for user: DaleSeo
# Fetching repositories for user: martindurant
# Fetching repositories for user: swalkinshaw
# Fetching repositories for user: jts
# Fetching repositories for user: heybereket
# Fetching repositories for user: ImranR98
# Fetching repositories for user: san089
# Fetching repositories for user: WolfgangOfner
# Fetching repositories for user: davellanedam
# Fetching repositories for user: shayanb
# Fetching repositories for user: piyush97
# Fetching repositories for user: fmfn
# Fetching repositories for user: ReikaKalseki
# Fetching repositories for user: antonitz
# Fetching repositories for user: itsdevbear
# Fetching repositories for user: phuc-mai
# Fetching repositories for user: maxhumber
# Fetching repositories for user: mszoek
# Fetching repositories for user: JacintoDesign
# Fetching repositories for user: djirdehh
# Fetching repositories for user: cnbeining
# Fetching repositories for user: aarnphm
# Fetching repositories for user: fardad
# Fetching repositories for user: n1ckfg
# Fetching repositories for user: cheezy
# Fetching repositories for user: chmln
# Fetching repositories for user: jobovy
# Fetching repositories for user: filippbudko
# Fetching repositories for user: henrytao-me
# Fetching repositories for user: michaelshimeles
# Fetching repositories for user: bruno-garcia
# Fetching repositories for user: fwang
# Fetching repositories for user: tomhodgins
# Fetching repositories for user: alicoding
# Fetching repositories for user: Devang-25
# Fetching repositories for user: deniseyu
# Fetching repositories for user: lextm
# Fetching repositories for user: t-mullen
# Fetching repositories for user: Tabrizian
# Fetching repositories for user: mystor
# Fetching repositories for user: una-dinosauria
# Fetching repositories for user: davepagurek
# Fetching repositories for user: indy256
# Fetching repositories for user: ethers-io
# Fetching repositories for user: xjasonlyu
# Fetching repositories for user: bioinformatics-ca
# Fetching repositories for user: kobiso
# Fetching repositories for user: RetroNick2020
# Fetching repositories for user: pycaret
# Fetching repositories for user: bowang-lab
# Fetching repositories for user: chesterbr
# Fetching repositories for user: laion01
# Fetching repositories for user: vasanthv
# Fetching repositories for user: shyndman
# Fetching repositories for user: xiaozhouwang
# Fetching repositories for user: pilwon
# Fetching repositories for user: moezbhatti
# Fetching repositories for user: iamnbutler
# Fetching repositories for user: danieldjohnson
# Fetching repositories for user: patcon
# Fetching repositories for user: alamkanak
# Fetching repositories for user: HackerYou
# Fetching repositories for user: tristen
# Fetching repositories for user: ryanshrott
# Fetching repositories for user: jneen
# Fetching repositories for user: Tech-With-Tim
# Fetching repositories for user: FrozenPandaz
# Fetching repositories for user: XanaduAI
# Fetching repositories for user: zoltan-nz
# Fetching repositories for user: BlakeBrown
# Fetching repositories for user: codewithchris
# Fetching repositories for user: alex-okrushko
# Fetching repositories for user: kelvinxu
# Fetching repositories for user: mahedee
# Fetching repositories for user: hannorein
# Fetching repositories for user: colinta
# Fetching repositories for user: alexminnaar
# Fetching repositories for user: jaseva
# Fetching repositories for user: syavash
# Fetching repositories for user: atesgoral
# Fetching repositories for user: andrewn6
# Fetching repositories for user: rileyjshaw
# Fetching repositories for user: sgbaird
# Fetching repositories for user: brenna
# Fetching repositories for user: joykare
# Fetching repositories for user: fmoliveira
# Fetching repositories for user: devinpleuler
# Fetching repositories for user: pritamworld
# Fetching repositories for user: vnmakarov
# Fetching repositories for user: websanova
# Fetching repositories for user: ritheshkumar95
# Fetching repositories for user: friyiajr
# Fetching repositories for user: dalenguyen
# Fetching repositories for user: makew0rld
# Fetching repositories for user: david-gpu
# Fetching repositories for user: amsul
# Fetching repositories for user: SteveJunGao
# Fetching repositories for user: VectorInstitute
# Fetching repositories for user: WilsonWangTHU
# Fetching repositories for user: mtrudel
# Fetching repositories for user: NickQiZhu
# Fetching repositories for user: Christopher2K
# Fetching repositories for user: for-ai
# Fetching repositories for user: JessicaLim8
# Fetching repositories for user: impressivewebs
# Fetching repositories for user: josh146
# Fetching repositories for user: mrisdal
# Fetching repositories for user: mstechly
# Fetching repositories for user: iSimar
# Fetching repositories for user: watadarkstar
# Fetching repositories for user: LuaxY
# Fetching repositories for user: danialfarid
# Fetching repositories for user: msantos
# Fetching repositories for user: brianpeiris
# Fetching repositories for user: jteneycke
# Fetching repositories for user: taras
# Fetching repositories for user: kinngh
# Fetching repositories for user: cpt-waffle
# Fetching repositories for user: thomas-lowry
# Fetching repositories for user: plentz
# Fetching repositories for user: ddavison
# Fetching repositories for user: Rayhane-mamah
# Fetching repositories for user: leebenson
# Fetching repositories for user: rgeirhos
# Fetching repositories for user: stevemar
# Fetching repositories for user: iKevinY
# Fetching repositories for user: arjungautam1
# Fetching repositories for user: filmaj
# Fetching repositories for user: MrGemy95
# Fetching repositories for user: MagicStack
# Fetching repositories for user: ElliotKillick
# Fetching repositories for user: thephoeron
# Fetching repositories for user: akshitac8
# Fetching repositories for user: interactiveimmersivehq
# Fetching repositories for user: theoomoregbee
# Fetching repositories for user: elbruno
# Fetching repositories for user: Hermanya
# Fetching repositories for user: janetacarr
# Fetching repositories for user: amacgregor
# Fetching repositories for user: kelvinlauKL
# Fetching repositories for user: chitwansaharia
# Fetching repositories for user: oalders
# Fetching repositories for user: Furkanzmc
# Fetching repositories for user: EverythingSuckz
# Fetching repositories for user: geographyclub
# Fetching repositories for user: therajanmaurya
# Fetching repositories for user: oliveiralecca
# Fetching repositories for user: QuLogic
# Fetching repositories for user: gizak
# Fetching repositories for user: epitron
# Fetching repositories for user: cameronmcnz
# Fetching repositories for user: mikkoh
# Fetching repositories for user: NoahDragon
# Fetching repositories for user: tomkralidis
# Fetching repositories for user: sebjai
# Fetching repositories for user: adryd325
# Fetching repositories for user: MJAlexander
# Fetching repositories for user: moezali1
# Fetching repositories for user: wohali
# Fetching repositories for user: mjangda
# Fetching repositories for user: DjDeveloperr
# Fetching repositories for user: JohnSully
# Fetching repositories for user: ericevenchick
# Fetching repositories for user: jess-data
# Fetching repositories for user: ReallySnow
# Fetching repositories for user: ylogx
# Fetching repositories for user: jeffrey-xiao
# Fetching repositories for user: marcospereira
# Fetching repositories for user: corbanbrook
# Fetching repositories for user: AutodeskAILab
# Fetching repositories for user: danqzq
# Fetching repositories for user: julianlam
# Fetching repositories for user: DateBro
# Fetching repositories for user: dashed
# Fetching repositories for user: keeferrourke
# Fetching repositories for user: aleemrehmtulla
# Fetching repositories for user: randyaajr
# Fetching repositories for user: Rchristiani
# Fetching repositories for user: moollaza
# Fetching repositories for user: jacobparis
# Fetching repositories for user: toksdotdev
# Fetching repositories for user: walkah
# Fetching repositories for user: erwanor
# Fetching repositories for user: ItsJonQ
# Fetching repositories for user: AndreiBarsan
# Fetching repositories for user: chocoluffy
# Fetching repositories for user: mfridman
# Fetching repositories for user: ruebot
# Fetching repositories for user: teamchong
# Fetching repositories for user: yawaramin
# Fetching repositories for user: fahdi
# Fetching repositories for user: teesloane
# Fetching repositories for user: truskovskiyk
# Fetching repositories for user: Continuities
# Fetching repositories for user: atgreen
# Fetching repositories for user: adriengivry
# Fetching repositories for user: hectris
# Fetching repositories for user: jules2689
# Fetching repositories for user: Sticktron
# Fetching repositories for user: pct960
# Fetching repositories for user: ehsan
# Fetching repositories for user: joshl26
# Fetching repositories for user: peterzhu2118
# Fetching repositories for user: arsduo
# Fetching repositories for user: prrao87
# Fetching repositories for user: kcnickerson
# Fetching repositories for user: TouchDesigner
# Fetching repositories for user: friendly
# Fetching repositories for user: knazeri
# Fetching repositories for user: andyw8
# Fetching repositories for user: seyonechithrananda
# Fetching repositories for user: ankonzoid
# Fetching repositories for user: markf94
# Fetching repositories for user: ansis
# Fetching repositories for user: bk2204
# Fetching repositories for user: alifa98
# Fetching repositories for user: m4mallu
# Fetching repositories for user: deluan
# Fetching repositories for user: hexonaut
# Fetching repositories for user: Danial-Kord
# Fetching repositories for user: joeyism
# Fetching repositories for user: HuguesTHOMAS
# Fetching repositories for user: spike01
# Fetching repositories for user: lacarmen
# Fetching repositories for user: yaoyaoding
# Fetching repositories for user: pushmatrix
# Fetching repositories for user: websemantics
# Fetching repositories for user: NorthernMan54
# Fetching repositories for user: SoroushMehraban
# Fetching repositories for user: ljdursi
# Fetching repositories for user: phillmv
# Fetching repositories for user: stevehu
# Fetching repositories for user: ChainSafeSystems
# Fetching repositories for user: tbabej
# Fetching repositories for user: ldct
# Fetching repositories for user: CNBorn
# Fetching repositories for user: DylanMeeus
# Fetching repositories for user: JohnGiorgi
# Fetching repositories for user: pschroen
# Fetching repositories for user: TroyKomodo
# Fetching repositories for user: HACKERALERT
# Fetching repositories for user: hammadshaikhha
# Fetching repositories for user: dilevin
# Fetching repositories for user: gregorycollins
# Fetching repositories for user: agile8118
# Fetching repositories for user: SandyLudosky
# Fetching repositories for user: bytenaija
# Fetching repositories for user: MatinTavakoli
# Fetching repositories for user: KingsMentor
# Fetching repositories for user: danielmoniz
# Fetching repositories for user: micdoodle8
# Fetching repositories for user: rishirdua
# Fetching repositories for user: hyfen
# Fetching repositories for user: topspinj
# Fetching repositories for user: jameskokoska
# Fetching repositories for user: lucas-manuel
# Fetching repositories for user: bredele
# Fetching repositories for user: tonybaltovski
# Fetching repositories for user: es
# Fetching repositories for user: flawnson
# Fetching repositories for user: svinkle
# Fetching repositories for user: brynnsmith
# Fetching repositories for user: rosszurowski
# Fetching repositories for user: nicholasaleks
# Fetching repositories for user: countcain
# Fetching repositories for user: upul
# Fetching repositories for user: kashav
# Fetching repositories for user: novatorem
# Fetching repositories for user: wealthsimple
# Fetching repositories for user: ShikharJ
# Fetching repositories for user: league1991
# Fetching repositories for user: suhaibaffan
# Fetching repositories for user: amlankar
# Fetching repositories for user: Xyene
# Fetching repositories for user: yashkant
# Fetching repositories for user: QuinntyneBrown
# Fetching repositories for user: lgfa29
# Fetching repositories for user: rafd
# Fetching repositories for user: caffeinum
# Fetching repositories for user: rafaelsteil
# Fetching repositories for user: RohanAlexander
# Fetching repositories for user: clouddrove
# Fetching repositories for user: utiasASRL
# Fetching repositories for user: mveytsman
# Fetching repositories for user: alex-wilmer
# Fetching repositories for user: colinbdclark
# Fetching repositories for user: cheapsteak
# Fetching repositories for user: MohamedSlah27
# Fetching repositories for user: nhat416
# Fetching repositories for user: ephread
# Fetching repositories for user: moaazsidat
# Fetching repositories for user: WirelessLife
# Fetching repositories for user: davedbase
# Fetching repositories for user: MrCheeze
# Fetching repositories for user: kpumuk
# Fetching repositories for user: Seanforfun
# Fetching repositories for user: JoshVarty
# Fetching repositories for user: richardwu
# Fetching repositories for user: 32teeth
# Fetching repositories for user: philchalmers
# Fetching repositories for user: pnitsch
# Fetching repositories for user: ahlashkari
# Fetching repositories for user: benhylau
# Fetching repositories for user: ahmdrefat
# Fetching repositories for user: mohamed-tayeh
# Fetching repositories for user: edmundnoble
# Fetching repositories for user: halostatue
# Fetching repositories for user: Xenomega
# Fetching repositories for user: 0xsauby
# Fetching repositories for user: jamesmacaulay
# Fetching repositories for user: JasonLovesDoggo
# Fetching repositories for user: asaikali
# Fetching repositories for user: ameliemaia
# Fetching repositories for user: invokethreatguy
# Fetching repositories for user: richgilbank
# Fetching repositories for user: Jeremboo
# Fetching repositories for user: AeroAndZero
# Fetching repositories for user: barisusakli
# Fetching repositories for user: marcelluscaio
# Fetching repositories for user: marcbensan
# Fetching repositories for user: 1Computer1
# Fetching repositories for user: xrenaa
# Fetching repositories for user: mssroboto
# Fetching repositories for user: distributethe6ix
# Fetching repositories for user: frank-liu-toronto
# Fetching repositories for user: quantum5
# Fetching repositories for user: bsormagec
# Fetching repositories for user: incizzle
# Fetching repositories for user: darcymason
# Fetching repositories for user: domluna
# Fetching repositories for user: andre-nguyen
# Fetching repositories for user: npow
# Fetching repositories for user: RaeesBhatti
# Fetching repositories for user: johnmal-dev
# Fetching repositories for user: tessus
# Fetching repositories for user: nathanmarks
# Fetching repositories for user: rafaelperez
# Fetching repositories for user: Abtinz
# Fetching repositories for user: manjitkumar
# Fetching repositories for user: jonathanlilly
# Fetching repositories for user: e-schultz
# Fetching repositories for user: itsflores
# Fetching repositories for user: CaydenPierce
# Fetching repositories for user: michaelstepner
# Fetching repositories for user: Abiodun-Shittu
# Fetching repositories for user: mikeboers
# Fetching repositories for user: Yifeng-He
# Fetching repositories for user: AtheMathmo
# Fetching repositories for user: gabrielgrant
# Fetching repositories for user: amanjeev
# Fetching repositories for user: dmitryrck
# Fetching repositories for user: danielsnider
# Fetching repositories for user: lsvekis
# Fetching repositories for user: jairojair
# Fetching repositories for user: marcgibbons
# Fetching repositories for user: daniellewebb-xx
# Fetching repositories for user: jbuck
# Fetching repositories for user: pangloss
# Fetching repositories for user: arieling
# Fetching repositories for user: carolinanonato
# Fetching repositories for user: johnantoni
# Fetching repositories for user: calvinlfer
# Fetching repositories for user: wgrathwohl
# Fetching repositories for user: psychobunny
# Fetching repositories for user: zazencodes
# Fetching repositories for user: baudehlo
# Fetching repositories for user: vodik
# Fetching repositories for user: rayryeng
# Fetching repositories for user: seglo
# Fetching repositories for user: william-tran
# Fetching repositories for user: zlovatt
# Fetching repositories for user: gaojunxuan
# Fetching repositories for user: nicholaschum
# Fetching repositories for user: Yumcoder-dev
# Fetching repositories for user: nicholas-tao
# Fetching repositories for user: joshspeagle
# Fetching repositories for user: crespire
# Fetching repositories for user: LucasBoTang
# Fetching repositories for user: ParsaMehdipour
# Fetching repositories for user: siebenmann
# Fetching repositories for user: Coldcard
# Fetching repositories for user: mikeconley
# Fetching repositories for user: jairajs89
# Fetching repositories for user: Shchvova
# Fetching repositories for user: rms80
# Fetching repositories for user: ArmanJR
# Fetching repositories for user: leibovic
# Fetching repositories for user: kintel
# Fetching repositories for user: bmarchete
# Fetching repositories for user: arkalim
# Fetching repositories for user: MichaelDiBernardo
# Fetching repositories for user: bwinton
# Fetching repositories for user: ahmadsalimi
# Fetching repositories for user: ueg1990
# Fetching repositories for user: jamaps
# Fetching repositories for user: fightingtheboss
# Fetching repositories for user: kracwarlock
# Fetching repositories for user: SteakEnthusiast
# Fetching repositories for user: myles
# Fetching repositories for user: ssydasheng
# Fetching repositories for user: Krutonium
# Fetching repositories for user: dvrzan
# Fetching repositories for user: Snivyn
# Fetching repositories for user: rajansagarwal
# Fetching repositories for user: BrityHemming
# Fetching repositories for user: aleccool213
# Fetching repositories for user: ikokkari
# Fetching repositories for user: akhomochkina
# Fetching repositories for user: ShayanDeSh
# Fetching repositories for user: takiszourntos
# Fetching repositories for user: chmodxx
# Fetching repositories for user: ababaian
# Fetching repositories for user: sedghi
# Fetching repositories for user: 1997alireza
# Fetching repositories for user: kieranrcampbell
# Fetching repositories for user: shinyorg
# Fetching repositories for user: jasongoodwin
# Fetching repositories for user: hhaidar
# Fetching repositories for user: tracymakes
# Fetching repositories for user: iBicha
# Fetching repositories for user: DillonN
# Fetching repositories for user: iancanada
# Fetching repositories for user: JohnOnSoftware
# Fetching repositories for user: wxs
# Fetching repositories for user: stephaniegiang
# Fetching repositories for user: dipikabh
# Fetching repositories for user: priom
# Fetching repositories for user: shonfeder
# Fetching repositories for user: yysun
# Fetching repositories for user: melaniesigrid
# Fetching repositories for user: Bortseb
# Fetching repositories for user: chyyran
# Fetching repositories for user: zoffixznet
# Fetching repositories for user: NS007-dev
# Fetching repositories for user: jrmuizel
# Fetching repositories for user: nickyiliwang
# Fetching repositories for user: supermacro
# Fetching repositories for user: farnoodma
# Fetching repositories for user: eltonvs
# Fetching repositories for user: rilian
# Fetching repositories for user: brvoigt
# Fetching repositories for user: Hardanish-Singh
# Fetching repositories for user: mstange
# Fetching repositories for user: adamfuhrer
# Fetching repositories for user: binyoon99
# Fetching repositories for user: rafkhan
# Fetching repositories for user: invisibleBully
# Fetching repositories for user: davifrossard
# Fetching repositories for user: blackHatMonkey
# Fetching repositories for user: thanethomson
# Fetching repositories for user: junzhengca
# Fetching repositories for user: AVAV2500
# Fetching repositories for user: rfratto
# Fetching repositories for user: nwjsmith
# Fetching repositories for user: shwina
# Fetching repositories for user: elliottsj
# Fetching repositories for user: NimaGhaedsharafi
# Fetching repositories for user: sumitarora
# Fetching repositories for user: seanpaultaylor
# Fetching repositories for user: probil
# Fetching repositories for user: bani
# Fetching repositories for user: liaojason2
# Fetching repositories for user: moein-shafi
# Fetching repositories for user: kyoshino
# Fetching repositories for user: scottclowe
# Fetching repositories for user: jinsley8
# Fetching repositories for user: caseware
# Fetching repositories for user: amangalvedhekar
# Fetching repositories for user: Prtfw
# Fetching repositories for user: haroldtreen
# Fetching repositories for user: liamks
# Fetching repositories for user: EmilyGraceSeville7cf
# Fetching repositories for user: Jerry1211
# Fetching repositories for user: ianmackenzie
# Fetching repositories for user: ppaquette
# Fetching repositories for user: kiosion
# Fetching repositories for user: rymcol
# Fetching repositories for user: quepol
# Fetching repositories for user: nlalonde
# Fetching repositories for user: jstaf
# Fetching repositories for user: NickStrupat
# Fetching repositories for user: nickpresta
# Fetching repositories for user: ChigboIO
# Fetching repositories for user: douglasmakey
# Fetching repositories for user: dgomesbr
# Fetching repositories for user: eadamceylan
# Fetching repositories for user: thejmazz
# Fetching repositories for user: michaelchi08
# Fetching repositories for user: jameskeane
# Fetching repositories for user: svanoort
# Fetching repositories for user: hannes-brt
# Fetching repositories for user: radioblahaj
# Fetching repositories for user: FabioBatSilva
# Fetching repositories for user: KooroshRH
# Fetching repositories for user: hrzafer
# Fetching repositories for user: sepehrasgarian
# Fetching repositories for user: prodseanb
# Fetching repositories for user: bgilham
# Fetching repositories for user: LeNPaul
# Fetching repositories for user: sauricat
# Fetching repositories for user: adamgoucher
# Fetching repositories for user: daniil
# Fetching repositories for user: ryanwilsonperkin
# Fetching repositories for user: aehlke
# Fetching repositories for user: stevenvachon
# Fetching repositories for user: matt-sd-watson
# Fetching repositories for user: MisterJimson
# Fetching repositories for user: cltrudeau
# Fetching repositories for user: goatandsheep
# Fetching repositories for user: uptoamir
# Fetching repositories for user: NodeBB
# Fetching repositories for user: spacejack
# Fetching repositories for user: gvarandas
# Fetching repositories for user: lunaroyster
# Fetching repositories for user: vikramkakkar
# Fetching repositories for user: destruc7i0n
# Fetching repositories for user: ranacseruet
# Fetching repositories for user: yusuf8ahmed
# Fetching repositories for user: yzgyyang
# Fetching repositories for user: WilliamPourmajidi
# Fetching repositories for user: SC4RECOIN
# Fetching repositories for user: gngdb
# Fetching repositories for user: samgermain
# Fetching repositories for user: adrian-miasik
# Fetching repositories for user: itaymishan
# Fetching repositories for user: UddamB
# Fetching repositories for user: jmcardon
# Fetching repositories for user: Shawn-Ogbomo
# Fetching repositories for user: gregr
# Fetching repositories for user: HaydenMeloche
# Fetching repositories for user: clarabatt
# Fetching repositories for user: yasith
# Fetching repositories for user: robocoder
# Fetching repositories for user: amingilani
# Fetching repositories for user: igilitschenski
# Fetching repositories for user: scoremedia
# Fetching repositories for user: awgeezrick
# Fetching repositories for user: AfzalivE
# Fetching repositories for user: zhangsu
# Fetching repositories for user: mabuyo
# Fetching repositories for user: mwarkentin
# Fetching repositories for user: rohithpudari
# Fetching repositories for user: HuakunShen
# Fetching repositories for user: mmonfared
# Fetching repositories for user: osis
# Fetching repositories for user: yangze0930
# Fetching repositories for user: aarongough
# Fetching repositories for user: npjd
# Fetching repositories for user: itsbilal
# Fetching repositories for user: sharon-yi
# Fetching repositories for user: dcooney
# Fetching repositories for user: PabloVallejo
# Fetching repositories for user: gmoledina
# Fetching repositories for user: mc256
# Fetching repositories for user: mlxd
# Fetching repositories for user: aravind-3105
# Fetching repositories for user: basil2style
# Fetching repositories for user: dellisd
# Fetching repositories for user: finiterank
# Fetching repositories for user: acode
# Fetching repositories for user: gorkem-cetin
# Fetching repositories for user: rwhogg
# Fetching repositories for user: andrewdamelio
# Fetching repositories for user: qasim
# Data saved successfully!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1
users = pd.read_csv('output/users.csv')
users.head()
# Out:
#           login            name   company         location  \
# 0      aneagoie  Andrei Neagoie       NaN  Toronto, Canada
# 1   ZhangMYihua     Yihua Zhang       NaN          Toronto
# 2   susanli2016        Susan Li       NaN   Toronto Canada
# 3  thedaviddias      David Dias  KIJIJICA  Toronto, Canada
# 4    ange-yaghi      Ange Yaghi       NaN          Toronto
#
#                    email hireable  \
# 0                    NaN     True
# 1  yihuazhang2@gmail.com      NaN
# 2                    NaN      NaN
# 3                    NaN      NaN
# 4       me@angeyaghi.com      NaN
#
#                                                  bio  public_repos  followers  \
# 0  Senior Software Dev turned Instructor. Founder...           145      10275
# 1                         Toronto Software Developer           143       5801
# 2                               Chief Data Scientist            34       4920
# 3  💻 Passionate Front-End Dev & 🎨 UI/UX fan. Cont...            88       4543
# 4                                      C++ Developer            32       4023
#
#    following            created_at
# 0          1  2015-01-30T17:05:43Z
# 1         11  2015-01-18T00:01:02Z
# 2         68  2016-11-28T04:22:39Z
# 3        302  2010-04-05T14:40:12Z
# 4         11  2016-07-13T21:01:21Z

# %%
users['hireable'] = users['hireable'].fillna(False).astype(bool)
# Out:
# <ipython-input-7-6ea7a0647cbf>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   users['hireable'] = users['hireable'].fillna(False).astype(bool)

# %%
top5 = users.sort_values(by='followers', ascending=False).head()
print(','.join(top5['login'].tolist()))
# Out:
# aneagoie,ZhangMYihua,susanli2016,thedaviddias,ange-yaghi

# %%
# 2
users['created_at'] = pd.to_datetime(users['created_at'])

# %%
top_earliest = users.sort_values(by='created_at').head()
print(','.join(top_earliest['login'].tolist()))
# Out:
# jamesmacaulay,michaelklishin,myles,nwjsmith,vito

# %%
# 3
repos = pd.read_csv('output/repositories.csv')
repos.head()
# Out:
#       login                                        full_name  \
# 0  aneagoie                                 aneagoie/3D_roll
# 1  aneagoie  aneagoie/advanced-React-Redux-Training-Jeopardy
# 2  aneagoie         aneagoie/advanced-redux-training-RoboDex
# 3  aneagoie                         aneagoie/AirBnB-template
# 4  aneagoie                               aneagoie/ajaxCalls
#
#              created_at  stargazers_count  watchers_count    language  \
# 0  2017-01-08T20:05:27Z                 0               0  JavaScript
# 1  2017-01-31T20:34:22Z                 1               1         CSS
# 2  2017-01-25T15:05:15Z                 1               1  JavaScript
# 3  2015-06-19T18:00:33Z                 1               1        HTML
# 4  2015-06-11T14:22:59Z                 0               0  JavaScript
#
#    has_projects  has_wiki license_name
# 0          True      True          NaN
# 1          True      True          NaN
# 2          True      True          NaN
# 3          True      True          NaN
# 4          True      True          NaN

# %%
repos['license_name'].value_counts().head(3)
# Out:
# license_name
# mit           14795
# other          4789
# apache-2.0     4579
# Name: count, dtype: int64

# %%
# 4
users['company'].value_counts().head(1)
# Out:
# company
# UNIVERSITY OF TORONTO    21
# Name: count, dtype: int64

# %%
# 5
repos['language'].value_counts().head(1)
# Out:
# language
# JavaScript    11211
# Name: count, dtype: int64

# %%
# 6
users_after_2020 = users[users['created_at'] > '2020-01-01']
users_after_2020.head()
# Out:
#            login           name        company         location email  \
# 52    enderh3art     Jesse Zhou            NaN          Toronto   NaN
# 62    iceburgcrm    Iceburg CRM            NaN  Toronto, Canada   NaN
# 79   HamedBahram   Hamed Bahram      STUDIO-HB      Toronto, CA   NaN
# 93    scrumtuous  Darcy DeClute     SCRUMTUOUS      Toronto, ON   NaN
# 105    barry-far       bardiafa  MIZEGERD-TECH      Toronto, ON   NaN
#
#      hireable                                                bio  \
# 52      False                                                NaN
# 62      False                                        Iceburg CRM
# 79       True  Software developer & content creator from Cana...
# 93      False  I'm a certified Scrum Master and AWS Cloud Pra...
# 105     False  "Don't let negativity dim your light; use it a...
#
#      public_repos  followers  following                created_at
# 52              5        922          7 2020-04-28 05:36:17+00:00
# 62              5        714      19957 2022-11-11 21:59:06+00:00
# 79             87        577          3 2020-04-22 13:56:33+00:00
# 93             16        535         90 2021-12-17 18:56:47+00:00
# 105             5        489         10 2023-09-04 06:25:14+00:00

# %%
repos_2020 = repos[repos['login'].isin(users_after_2020['login'].tolist())]
repos_2020['language'].value_counts().head()
# Out:
# language
# JavaScript    338
# TypeScript    205
# Python        161
# HTML          122
# CSS            61
# Name: count, dtype: int64

# %%
# 7
avg_stars = repos.groupby('language')['stargazers_count'].mean()
top_lang = avg_stars.idxmax()
top_stars = avg_stars.max()
print(top_lang, top_stars)
# Out:
# Cython 1780.6666666666667

# %%
# 8
users['leader_strength'] = users['followers'] / (1 + users['following'])
top5_lead = users.sort_values(by='leader_strength', ascending=False).head()
print(','.join(top5_lead['login'].tolist()))
# Out:
# aneagoie,nayuki,GrapheneOS,hlissner,rspivak

# %%
# 9
correlation = users['followers'].corr(users['public_repos'])
correlation
# Out:
# 0.055494208605130095

# %%
# 10
import csv
followers = []
public_repos = []
with open('output/users.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        followers_count = int(row['followers'])
        public_repos_count = int(row['public_repos'])
        followers.append(followers_count)
        public_repos.append(public_repos_count)
if len(followers) > 1 and len(public_repos) > 1:
    slope, intercept = np.polyfit(public_repos, followers, 1)

    print(f"{slope:.3f}")
else:
    print("Error")
# Out:
# 0.253

# %%
# 11
if repos['has_projects'].dtype == 'object':
    repos['has_projects'] = repos['has_projects'].map({'true': True, 'false': False})
if repos['has_wiki'].dtype == 'object':
    repos['has_wiki'] = repos['has_wiki'].map({'true': True, 'false': False})

correlation = repos['has_projects'].corr(repos['has_wiki'])

print(round(correlation, 3))
# Out:
# 0.353

# %%
# 12
hireable_avg_following = users[users['hireable'] == True]['following'].mean()
non_hireable_avg_following = users[users['hireable'] == False]['following'].mean()
difference = hireable_avg_following - non_hireable_avg_following
difference
# Out:
# -13.248392469786182

# %%
# 13
from sklearn.linear_model import LinearRegression
users_with_bio = users[(users['bio'].notna()) & (users['bio'] != '')].copy()
users_with_bio.loc[:, 'bio_len'] = users_with_bio['bio'].str.len()

X = users_with_bio['bio_len'].values.reshape(-1,1)
y = users_with_bio['followers']

lr2 = LinearRegression()
lr2.fit(X, y)
lr2.coef_[0]
# Out:
# 1.407117262498666

# %%
# 14
import csv
from collections import Counter
from datetime import datetime

weekend_repo_counts = Counter()

with open('output/repositories.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    for row in reader:
        created_at = row.get('created_at', '')
        if created_at:
            created_date = datetime.fromisoformat(created_at[:-1])

            if created_date.weekday() in [5, 6]:
                user_login = row['login']
                weekend_repo_counts[user_login] += 1

top_users = weekend_repo_counts.most_common(5)

top_logins = [user[0] for user in top_users]

print(','.join(top_logins))
# Out:
# n1ckfg,jsoref,QuinntyneBrown,invokethreatguy,andyw8

# %%
# 15
fraction_hierable = users[users['hireable'] == True]['email'].notna().mean()
fraction_non_hierable = users[users['hireable'] == False]['email'].notna().mean()
diff = fraction_hierable - fraction_non_hierable
diff
# Out:
# 0.13476138828633405

# %%
# 16
new_users = users[users['name'].notna()].copy()
new_users['surname'] = new_users['name'].str.split().str[-1].str.strip()
surname_counts = new_users['surname'].value_counts()
max_count = surname_counts.max()
common_surnames = surname_counts[surname_counts == max_count].index.tolist()
common_surnames.sort()
print(','.join(common_surnames))
# Out:
# Ahmed
