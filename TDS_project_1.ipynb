# %%
import requests
import csv
import time

# GitHub API token
GITHUB_TOKEN = 'SECRET_TOKEN'
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

# Helper function to clean up company names
def clean_company_name(company):
    if company:
        company = company.strip().lstrip('@').upper()
    return company

# Function to fetch users from the GitHub API
def fetch_users(city="Toronto", min_followers=100):
    users = []
    page = 1

    while True:
        url = f"https://api.github.com/search/users?q=location:{city}+followers:>{min_followers}&page={page}&per_page=100"
        response = requests.get(url, headers=HEADERS)
        data = response.json()

        # Break if no more results
        if 'items' not in data or not data['items']:
            break

        for user in data['items']:
            # Get full user info
            user_url = user['url']
            user_response = requests.get(user_url, headers=HEADERS)
            user_data = user_response.json()

            # Extract required fields
            users.append({
                'login': user_data['login'],
                'name': user_data['name'],
                'company': clean_company_name(user_data['company']),
                'location': user_data['location'],
                'email': user_data['email'],
                'hireable': user_data['hireable'],
                'bio': user_data['bio'],
                'public_repos': user_data['public_repos'],
                'followers': user_data['followers'],
                'following': user_data['following'],
                'created_at': user_data['created_at'],
            })
        page += 1
        time.sleep(1)  # Avoid hitting API rate limits

    return users

# Function to fetch repositories for a user
def fetch_repositories(user_login):
    repositories = []
    page = 1

    while True:
        url = f"https://api.github.com/users/{user_login}/repos?per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        repo_data = response.json()

        # Break if no more repositories
        if not repo_data:
            break

        for repo in repo_data:
            repositories.append({
                'login': user_login,
                'full_name': repo['full_name'],
                'created_at': repo['created_at'],
                'stargazers_count': repo['stargazers_count'],
                'watchers_count': repo['watchers_count'],
                'language': repo['language'],
                'has_projects': repo['has_projects'],
                'has_wiki': repo['has_wiki'],
                'license_name': repo['license']['key'] if repo['license'] else None,
            })

        # If fewer than 100 repositories are returned, it means we're on the last page
        if len(repo_data) < 100:
            break

        page += 1  # Move to the next page
        time.sleep(1)  # Avoid hitting API rate limits

    return repositories

# Save users to CSV
def save_users_to_csv(users, filename="users.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=users[0].keys())
        writer.writeheader()
        writer.writerows(users)

# Save repositories to CSV
def save_repositories_to_csv(repositories, filename="repositories_unformat.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=repositories[0].keys())
        writer.writeheader()
        writer.writerows(repositories)

def main():
    print("Fetching users...")
    users = fetch_users()
    save_users_to_csv(users)
    print(f"Saved {len(users)} users to users.csv")

    print("Fetching repositories...")
    all_repositories = []
    for user in users:
        user_repos = fetch_repositories(user["login"])
        all_repositories.extend(user_repos)
        print(f"Fetched {len(user_repos)} repositories for user {user['login']}")

    save_repositories_to_csv(all_repositories)
    print(f"Saved {len(all_repositories)} repositories to repositories_unformat.csv")

if __name__ == "__main__":
    main()
# Out:
# Fetching users...
# Saved 685 users to users.csv
# Fetching repositories...
# Fetched 145 repositories for user aneagoie
# Fetched 143 repositories for user ZhangMYihua
# Fetched 34 repositories for user susanli2016
# Fetched 88 repositories for user thedaviddias
# Fetched 32 repositories for user ange-yaghi
# Fetched 31 repositories for user nayuki
# Fetched 128 repositories for user stemmlerjs
# Fetched 184 repositories for user GrapheneOS
# Fetched 335 repositories for user MylesBorins
# Fetched 158 repositories for user vsavkin
# Fetched 38 repositories for user kevinjycui
# Fetched 60 repositories for user hlissner
# Fetched 16 repositories for user gazijarin
# Fetched 23 repositories for user priya-dwivedi
# Fetched 1 repositories for user dmitshur
# Fetched 14 repositories for user rspivak
# Fetched 69 repositories for user daattali
# Fetched 51 repositories for user chenyuntc
# Fetched 2 repositories for user jmorganca
# Fetched 135 repositories for user petertodd
# Fetched 490 repositories for user vladikoff
# Fetched 175 repositories for user michaelklishin
# Fetched 46 repositories for user raganwald
# Fetched 139 repositories for user dsherret
# Fetched 128 repositories for user codereport
# Fetched 86 repositories for user darcyclarke
# Fetched 62 repositories for user adam-p
# Fetched 152 repositories for user richlander
# Fetched 51 repositories for user rich-iannone
# Fetched 63 repositories for user ricmoo
# Fetched 167 repositories for user TarrySingh
# Fetched 76 repositories for user 1Password
# Fetched 84 repositories for user ehoneahobed
# Fetched 88 repositories for user craffel
# Fetched 51 repositories for user wiseodd
# Fetched 84 repositories for user markstory
# Fetched 169 repositories for user JasonEtco
# Fetched 129 repositories for user jtemporal
# Fetched 189 repositories for user alecjacobson
# Fetched 95 repositories for user Gaohaoyang
# Fetched 218 repositories for user shazow
# Fetched 245 repositories for user leighhalliday
# Fetched 232 repositories for user winkerVSbecks
# Fetched 31 repositories for user luisguiserrano
# Fetched 85 repositories for user sachac
# Fetched 82 repositories for user ziishaned
# Fetched 130 repositories for user abbycabs
# Fetched 216 repositories for user yogthos
# Fetched 50 repositories for user JunMa11
# Fetched 204 repositories for user caitp
# Fetched 384 repositories for user k88hudson
# Fetched 33 repositories for user gvwilson
# Fetched 5 repositories for user enderh3art
# Fetched 166 repositories for user ninjamuffin99
# Fetched 105 repositories for user Rishit-dagli
# Fetched 33 repositories for user BenEmdon
# Fetched 74 repositories for user hejazizo
# Fetched 59 repositories for user aritchie
# Fetched 41 repositories for user jgrandja
# Fetched 219 repositories for user lazerwalker
# Fetched 17 repositories for user xinshuoweng
# Fetched 81 repositories for user pkieltyka
# Fetched 5 repositories for user iceburgcrm
# Fetched 26 repositories for user iH8sn0w
# Fetched 110 repositories for user ahmadnassri
# Fetched 68 repositories for user zackradisic
# Fetched 393 repositories for user ChainSafe
# Fetched 55 repositories for user OlivierLaflamme
# Fetched 26 repositories for user lstein
# Fetched 319 repositories for user jaysoo
# Fetched 28 repositories for user benvinegar
# Fetched 20 repositories for user davidrosenberg
# Fetched 35 repositories for user Idnan
# Fetched 257 repositories for user rokon12
# Fetched 128 repositories for user eviltrout
# Fetched 34 repositories for user vipulasri
# Fetched 29 repositories for user jamesagnew
# Fetched 149 repositories for user spencermountain
# Fetched 257 repositories for user vito
# Fetched 87 repositories for user HamedBahram
# Fetched 34 repositories for user ibraheemdev
# Fetched 7 repositories for user olado
# Fetched 176 repositories for user steveseguin
# Fetched 109 repositories for user fantix
# Fetched 125 repositories for user gf3
# Fetched 505 repositories for user GunterMueller
# Fetched 114 repositories for user FaisalAbid
# Fetched 54 repositories for user mhammond
# Fetched 36 repositories for user odziem
# Fetched 26 repositories for user glouw
# Fetched 148 repositories for user cenkalti
# Fetched 65 repositories for user Windscribe
# Fetched 33 repositories for user anniebombanie
# Fetched 2085 repositories for user jsoref
# Fetched 16 repositories for user scrumtuous
# Fetched 85 repositories for user nikolovlazar
# Fetched 71 repositories for user mobinni
# Fetched 70 repositories for user kulkarniankita
# Fetched 18 repositories for user ploopyco
# Fetched 176 repositories for user DylanVann
# Fetched 216 repositories for user dnephin
# Fetched 48 repositories for user abetlen
# Fetched 123 repositories for user code-shoily
# Fetched 20 repositories for user tsiliopoulos
# Fetched 27 repositories for user josh0xA
# Fetched 5 repositories for user barry-far
# Fetched 19 repositories for user npapernot
# Fetched 43 repositories for user kamiyaa
# Fetched 27 repositories for user OmarElgabry
# Fetched 62 repositories for user sideeffects
# Fetched 37 repositories for user AtotheY
# Fetched 6 repositories for user r-park
# Fetched 14 repositories for user tristanhimmelman
# Fetched 416 repositories for user rgrinberg
# Fetched 68 repositories for user jaberg
# Fetched 21 repositories for user Wuziyi616
# Fetched 33 repositories for user etimberg
# Fetched 47 repositories for user ExamProCo
# Fetched 19 repositories for user GeorgeSeif
# Fetched 368 repositories for user st3fan
# Fetched 168 repositories for user DaleSeo
# Fetched 116 repositories for user wolever
# Fetched 164 repositories for user martindurant
# Fetched 46 repositories for user swalkinshaw
# Fetched 61 repositories for user jts
# Fetched 34 repositories for user heybereket
# Fetched 48 repositories for user ImranR98
# Fetched 34 repositories for user san089
# Fetched 6 repositories for user davellanedam
# Fetched 102 repositories for user WolfgangOfner
# Fetched 109 repositories for user piyush97
# Fetched 107 repositories for user ReikaKalseki
# Fetched 13 repositories for user fmfn
# Fetched 173 repositories for user shayanb
# Fetched 30 repositories for user antonitz
# Fetched 52 repositories for user phuc-mai
# Fetched 74 repositories for user itsdevbear
# Fetched 35 repositories for user aarnphm
# Fetched 8 repositories for user mszoek
# Fetched 42 repositories for user maxhumber
# Fetched 55 repositories for user JacintoDesign
# Fetched 135 repositories for user cnbeining
# Fetched 38 repositories for user djirdehh
# Fetched 4 repositories for user fardad
# Fetched 1988 repositories for user n1ckfg
# Fetched 31 repositories for user michaelshimeles
# Fetched 46 repositories for user cheezy
# Fetched 38 repositories for user chmln
# Fetched 91 repositories for user jobovy
# Fetched 60 repositories for user henrytao-me
# Fetched 14 repositories for user filippbudko
# Fetched 70 repositories for user bruno-garcia
# Fetched 142 repositories for user tomhodgins
# Fetched 74 repositories for user fwang
# Fetched 209 repositories for user alicoding
# Fetched 319 repositories for user Devang-25
# Fetched 169 repositories for user deniseyu
# Fetched 117 repositories for user lextm
# Fetched 34 repositories for user Tabrizian
# Fetched 68 repositories for user t-mullen
# Fetched 213 repositories for user mystor
# Fetched 27 repositories for user una-dinosauria
# Fetched 128 repositories for user davepagurek
# Fetched 7 repositories for user indy256
# Fetched 60 repositories for user xjasonlyu
# Fetched 30 repositories for user ethers-io
# Fetched 28 repositories for user bioinformatics-ca
# Fetched 169 repositories for user RetroNick2020
# Fetched 44 repositories for user bowang-lab
# Fetched 51 repositories for user kobiso
# Fetched 59 repositories for user pycaret
# Fetched 126 repositories for user laion01
# Fetched 57 repositories for user chesterbr
# Fetched 25 repositories for user vasanthv
# Fetched 118 repositories for user shyndman
# Fetched 24 repositories for user xiaozhouwang
# Fetched 58 repositories for user pilwon
# Fetched 3 repositories for user moezbhatti
# Fetched 95 repositories for user iamnbutler
# Fetched 22 repositories for user danieldjohnson
# Fetched 647 repositories for user patcon
# Fetched 34 repositories for user alamkanak
# Fetched 83 repositories for user HackerYou
# Fetched 64 repositories for user tristen
# Fetched 37 repositories for user ryanshrott
# Fetched 142 repositories for user jneen
# Fetched 7 repositories for user Tech-With-Tim
# Fetched 104 repositories for user FrozenPandaz
# Fetched 76 repositories for user XanaduAI
# Fetched 33 repositories for user jaseva
# Fetched 23 repositories for user codewithchris
# Fetched 255 repositories for user zoltan-nz
# Fetched 33 repositories for user BlakeBrown
# Fetched 33 repositories for user alex-okrushko
# Fetched 197 repositories for user mahedee
# Fetched 127 repositories for user hannorein
# Fetched 38 repositories for user kelvinxu
# Fetched 130 repositories for user colinta
# Fetched 108 repositories for user alexminnaar
# Fetched 11 repositories for user syavash
# Fetched 142 repositories for user atesgoral
# Fetched 244 repositories for user andrewn6
# Fetched 237 repositories for user rileyjshaw
# Fetched 97 repositories for user sgbaird
# Fetched 56 repositories for user joykare
# Fetched 44 repositories for user brenna
# Fetched 147 repositories for user fmoliveira
# Fetched 11 repositories for user devinpleuler
# Fetched 484 repositories for user pritamworld
# Fetched 4 repositories for user vnmakarov
# Fetched 28 repositories for user websanova
# Fetched 36 repositories for user ritheshkumar95
# Fetched 111 repositories for user dalenguyen
# Fetched 51 repositories for user friyiajr
# Fetched 66 repositories for user makew0rld
# Fetched 15 repositories for user SteveJunGao
# Fetched 3 repositories for user david-gpu
# Fetched 54 repositories for user amsul
# Fetched 28 repositories for user for-ai
# Fetched 58 repositories for user Christopher2K
# Fetched 101 repositories for user VectorInstitute
# Fetched 53 repositories for user WilsonWangTHU
# Fetched 97 repositories for user mtrudel
# Fetched 15 repositories for user NickQiZhu
# Fetched 34 repositories for user JessicaLim8
# Fetched 70 repositories for user impressivewebs
# Fetched 10 repositories for user mrisdal
# Fetched 30 repositories for user josh146
# Fetched 41 repositories for user mstechly
# Fetched 54 repositories for user iSimar
# Fetched 116 repositories for user watadarkstar
# Fetched 111 repositories for user LuaxY
# Fetched 28 repositories for user danialfarid
# Fetched 137 repositories for user msantos
# Fetched 201 repositories for user brianpeiris
# Fetched 84 repositories for user jteneycke
# Fetched 267 repositories for user taras
# Fetched 16 repositories for user kinngh
# Fetched 72 repositories for user cpt-waffle
# Fetched 20 repositories for user thomas-lowry
# Fetched 6 repositories for user plentz
# Fetched 99 repositories for user ddavison
# Fetched 5 repositories for user Rayhane-mamah
# Fetched 95 repositories for user stevemar
# Fetched 18 repositories for user leebenson
# Fetched 11 repositories for user rgeirhos
# Fetched 14 repositories for user MagicStack
# Fetched 21 repositories for user iKevinY
# Fetched 143 repositories for user arjungautam1
# Fetched 235 repositories for user filmaj
# Fetched 15 repositories for user MrGemy95
# Fetched 62 repositories for user thephoeron
# Fetched 15 repositories for user ElliotKillick
# Fetched 80 repositories for user akshitac8
# Fetched 21 repositories for user interactiveimmersivehq
# Fetched 113 repositories for user elbruno
# Fetched 91 repositories for user theoomoregbee
# Fetched 133 repositories for user Hermanya
# Fetched 51 repositories for user janetacarr
# Fetched 52 repositories for user kelvinlauKL
# Fetched 62 repositories for user amacgregor
# Fetched 48 repositories for user chitwansaharia
# Fetched 161 repositories for user oalders
# Fetched 82 repositories for user Furkanzmc
# Fetched 152 repositories for user therajanmaurya
# Fetched 9 repositories for user geographyclub
# Fetched 38 repositories for user EverythingSuckz
# Fetched 76 repositories for user cameronmcnz
# Fetched 43 repositories for user oliveiralecca
# Fetched 314 repositories for user QuLogic
# Fetched 37 repositories for user gizak
# Fetched 103 repositories for user epitron
# Fetched 154 repositories for user tomkralidis
# Fetched 80 repositories for user mikkoh
# Fetched 15 repositories for user sebjai
# Fetched 52 repositories for user NoahDragon
# Fetched 79 repositories for user adryd325
# Fetched 36 repositories for user MJAlexander
# Fetched 21 repositories for user moezali1
# Fetched 37 repositories for user wohali
# Fetched 42 repositories for user mjangda
# Fetched 149 repositories for user DjDeveloperr
# Fetched 11 repositories for user ReallySnow
# Fetched 29 repositories for user JohnSully
# Fetched 71 repositories for user ericevenchick
# Fetched 6 repositories for user jess-data
# Fetched 90 repositories for user ylogx
# Fetched 62 repositories for user corbanbrook
# Fetched 21 repositories for user danqzq
# Fetched 82 repositories for user jeffrey-xiao
# Fetched 69 repositories for user marcospereira
# Fetched 155 repositories for user julianlam
# Fetched 18 repositories for user AutodeskAILab
# Fetched 34 repositories for user DateBro
# Fetched 26 repositories for user aleemrehmtulla
# Fetched 176 repositories for user dashed
# Fetched 37 repositories for user keeferrourke
# Fetched 151 repositories for user Rchristiani
# Fetched 10 repositories for user moollaza
# Fetched 59 repositories for user randyaajr
# Fetched 148 repositories for user jacobparis
# Fetched 30 repositories for user toksdotdev
# Fetched 54 repositories for user walkah
# Fetched 212 repositories for user erwanor
# Fetched 256 repositories for user ItsJonQ
# Fetched 50 repositories for user AndreiBarsan
# Fetched 310 repositories for user teamchong
# Fetched 63 repositories for user mfridman
# Fetched 145 repositories for user chocoluffy
# Fetched 79 repositories for user ruebot
# Fetched 32 repositories for user hectris
# Fetched 33 repositories for user truskovskiyk
# Fetched 120 repositories for user yawaramin
# Fetched 271 repositories for user fahdi
# Fetched 25 repositories for user teesloane
# Fetched 2 repositories for user kcnickerson
# Fetched 71 repositories for user Continuities
# Fetched 245 repositories for user atgreen
# Fetched 50 repositories for user adriengivry
# Fetched 108 repositories for user jules2689
# Fetched 30 repositories for user Sticktron
# Fetched 42 repositories for user pct960
# Fetched 139 repositories for user ehsan
# Fetched 56 repositories for user peterzhu2118
# Fetched 67 repositories for user prrao87
# Fetched 14 repositories for user TouchDesigner
# Fetched 55 repositories for user friendly
# Fetched 77 repositories for user arsduo
# Fetched 82 repositories for user joshl26
# Fetched 16 repositories for user knazeri
# Fetched 44 repositories for user seyonechithrananda
# Fetched 472 repositories for user andyw8
# Fetched 29 repositories for user markf94
# Fetched 4 repositories for user ankonzoid
# Fetched 23 repositories for user ansis
# Fetched 109 repositories for user bk2204
# Fetched 40 repositories for user m4mallu
# Fetched 86 repositories for user deluan
# Fetched 58 repositories for user alifa98
# Fetched 48 repositories for user Danial-Kord
# Fetched 148 repositories for user joeyism
# Fetched 97 repositories for user hexonaut
# Fetched 10 repositories for user HuguesTHOMAS
# Fetched 96 repositories for user spike01
# Fetched 22 repositories for user lacarmen
# Fetched 39 repositories for user yaoyaoding
# Fetched 99 repositories for user pushmatrix
# Fetched 121 repositories for user websemantics
# Fetched 96 repositories for user NorthernMan54
# Fetched 70 repositories for user ljdursi
# Fetched 52 repositories for user phillmv
# Fetched 43 repositories for user SoroushMehraban
# Fetched 6 repositories for user stevehu
# Fetched 20 repositories for user ChainSafeSystems
# Fetched 113 repositories for user tbabej
# Fetched 181 repositories for user ldct
# Fetched 25 repositories for user CNBorn
# Fetched 128 repositories for user DylanMeeus
# Fetched 96 repositories for user JohnGiorgi
# Fetched 32 repositories for user pschroen
# Fetched 24 repositories for user HACKERALERT
# Fetched 26 repositories for user TroyKomodo
# Fetched 9 repositories for user hammadshaikhha
# Fetched 37 repositories for user agile8118
# Fetched 58 repositories for user SandyLudosky
# Fetched 37 repositories for user dilevin
# Fetched 31 repositories for user gregorycollins
# Fetched 131 repositories for user bytenaija
# Fetched 24 repositories for user MatinTavakoli
# Fetched 85 repositories for user KingsMentor
# Fetched 70 repositories for user danielmoniz
# Fetched 19 repositories for user micdoodle8
# Fetched 33 repositories for user rishirdua
# Fetched 44 repositories for user hyfen
# Fetched 17 repositories for user topspinj
# Fetched 295 repositories for user bredele
# Fetched 41 repositories for user jameskokoska
# Fetched 34 repositories for user lucas-manuel
# Fetched 53 repositories for user tonybaltovski
# Fetched 26 repositories for user nicholasaleks
# Fetched 79 repositories for user es
# Fetched 23 repositories for user flawnson
# Fetched 25 repositories for user svinkle
# Fetched 19 repositories for user brynnsmith
# Fetched 29 repositories for user rosszurowski
# Fetched 12 repositories for user countcain
# Fetched 65 repositories for user upul
# Fetched 111 repositories for user wealthsimple
# Fetched 36 repositories for user kashav
# Fetched 21 repositories for user novatorem
# Fetched 41 repositories for user ShikharJ
# Fetched 19 repositories for user league1991
# Fetched 1216 repositories for user QuinntyneBrown
# Fetched 13 repositories for user amlankar
# Fetched 88 repositories for user Xyene
# Fetched 33 repositories for user yashkant
# Fetched 90 repositories for user suhaibaffan
# Fetched 148 repositories for user caffeinum
# Fetched 126 repositories for user lgfa29
# Fetched 55 repositories for user rafd
# Fetched 8 repositories for user rafaelsteil
# Fetched 123 repositories for user RohanAlexander
# Fetched 69 repositories for user utiasASRL
# Fetched 195 repositories for user clouddrove
# Fetched 172 repositories for user mveytsman
# Fetched 200 repositories for user alex-wilmer
# Fetched 147 repositories for user colinbdclark
# Fetched 178 repositories for user cheapsteak
# Fetched 6 repositories for user MohamedSlah27
# Fetched 618 repositories for user nhat416
# Fetched 25 repositories for user ephread
# Fetched 154 repositories for user moaazsidat
# Fetched 19 repositories for user WirelessLife
# Fetched 23 repositories for user davedbase
# Fetched 38 repositories for user kpumuk
# Fetched 66 repositories for user MrCheeze
# Fetched 23 repositories for user Seanforfun
# Fetched 76 repositories for user 32teeth
# Fetched 78 repositories for user JoshVarty
# Fetched 47 repositories for user richardwu
# Fetched 95 repositories for user ahmdrefat
# Fetched 10 repositories for user philchalmers
# Fetched 8 repositories for user pnitsch
# Fetched 12 repositories for user ahlashkari
# Fetched 65 repositories for user benhylau
# Fetched 22 repositories for user mohamed-tayeh
# Fetched 143 repositories for user edmundnoble
# Fetched 81 repositories for user halostatue
# Fetched 7 repositories for user 0xsauby
# Fetched 59 repositories for user jamesmacaulay
# Fetched 55 repositories for user JasonLovesDoggo
# Fetched 112 repositories for user asaikali
# Fetched 8 repositories for user ameliemaia
# Fetched 874 repositories for user invokethreatguy
# Fetched 41 repositories for user xrenaa
# Fetched 7 repositories for user Xenomega
# Fetched 60 repositories for user richgilbank
# Fetched 37 repositories for user Jeremboo
# Fetched 31 repositories for user AeroAndZero
# Fetched 113 repositories for user barisusakli
# Fetched 79 repositories for user marcelluscaio
# Fetched 34 repositories for user distributethe6ix
# Fetched 12 repositories for user darcymason
# Fetched 54 repositories for user 1Computer1
# Fetched 19 repositories for user marcbensan
# Fetched 6 repositories for user mssroboto
# Fetched 11 repositories for user frank-liu-toronto
# Fetched 88 repositories for user quantum5
# Fetched 207 repositories for user bsormagec
# Fetched 21 repositories for user incizzle
# Fetched 53 repositories for user RaeesBhatti
# Fetched 138 repositories for user domluna
# Fetched 86 repositories for user andre-nguyen
# Fetched 170 repositories for user npow
# Fetched 42 repositories for user johnmal-dev
# Fetched 94 repositories for user tessus
# Fetched 47 repositories for user ParsaMehdipour
# Fetched 91 repositories for user nathanmarks
# Fetched 59 repositories for user rafaelperez
# Fetched 44 repositories for user manjitkumar
# Fetched 10 repositories for user jonathanlilly
# Fetched 53 repositories for user Abtinz
# Fetched 139 repositories for user e-schultz
# Fetched 37 repositories for user itsflores
# Fetched 35 repositories for user CaydenPierce
# Fetched 21 repositories for user michaelstepner
# Fetched 49 repositories for user Abiodun-Shittu
# Fetched 67 repositories for user mikeboers
# Fetched 29 repositories for user Yifeng-He
# Fetched 56 repositories for user AtheMathmo
# Fetched 117 repositories for user dmitryrck
# Fetched 180 repositories for user gabrielgrant
# Fetched 81 repositories for user amanjeev
# Fetched 122 repositories for user danielsnider
# Fetched 30 repositories for user lsvekis
# Fetched 5 repositories for user jairojair
# Fetched 62 repositories for user marcgibbons
# Fetched 126 repositories for user calvinlfer
# Fetched 11 repositories for user daniellewebb-xx
# Fetched 261 repositories for user jbuck
# Fetched 117 repositories for user pangloss
# Fetched 105 repositories for user carolinanonato
# Fetched 54 repositories for user arieling
# Fetched 535 repositories for user johnantoni
# Fetched 24 repositories for user wgrathwohl
# Fetched 116 repositories for user psychobunny
# Fetched 68 repositories for user zazencodes
# Fetched 39 repositories for user baudehlo
# Fetched 155 repositories for user vodik
# Fetched 25 repositories for user rayryeng
# Fetched 103 repositories for user seglo
# Fetched 59 repositories for user william-tran
# Fetched 14 repositories for user zlovatt
# Fetched 56 repositories for user gaojunxuan
# Fetched 16 repositories for user nicholaschum
# Fetched 60 repositories for user Yumcoder-dev
# Fetched 5 repositories for user SteakEnthusiast
# Fetched 23 repositories for user nicholas-tao
# Fetched 20 repositories for user joshspeagle
# Fetched 108 repositories for user crespire
# Fetched 44 repositories for user LucasBoTang
# Fetched 31 repositories for user siebenmann
# Fetched 16 repositories for user Coldcard
# Fetched 132 repositories for user mikeconley
# Fetched 53 repositories for user bmarchete
# Fetched 33 repositories for user jairajs89
# Fetched 78 repositories for user Shchvova
# Fetched 9 repositories for user rms80
# Fetched 43 repositories for user ArmanJR
# Fetched 88 repositories for user leibovic
# Fetched 62 repositories for user kintel
# Fetched 32 repositories for user arkalim
# Fetched 45 repositories for user ueg1990
# Fetched 29 repositories for user MichaelDiBernardo
# Fetched 98 repositories for user bwinton
# Fetched 42 repositories for user ahmadsalimi
# Fetched 47 repositories for user sedghi
# Fetched 39 repositories for user jamaps
# Fetched 42 repositories for user fightingtheboss
# Fetched 42 repositories for user kracwarlock
# Fetched 215 repositories for user myles
# Fetched 8 repositories for user ssydasheng
# Fetched 9 repositories for user dvrzan
# Fetched 12 repositories for user Snivyn
# Fetched 144 repositories for user rajansagarwal
# Fetched 95 repositories for user BrityHemming
# Fetched 70 repositories for user aleccool213
# Fetched 20 repositories for user ikokkari
# Fetched 211 repositories for user Krutonium
# Fetched 14 repositories for user akhomochkina
# Fetched 25 repositories for user ShayanDeSh
# Fetched 17 repositories for user takiszourntos
# Fetched 6 repositories for user chmodxx
# Fetched 46 repositories for user ababaian
# Fetched 35 repositories for user 1997alireza
# Fetched 56 repositories for user kieranrcampbell
# Fetched 14 repositories for user shinyorg
# Fetched 105 repositories for user priom
# Fetched 69 repositories for user jasongoodwin
# Fetched 71 repositories for user hhaidar
# Fetched 15 repositories for user tracymakes
# Fetched 43 repositories for user iBicha
# Fetched 8 repositories for user DillonN
# Fetched 8 repositories for user iancanada
# Fetched 49 repositories for user JohnOnSoftware
# Fetched 62 repositories for user supermacro
# Fetched 36 repositories for user Bortseb
# Fetched 32 repositories for user wxs
# Fetched 12 repositories for user stephaniegiang
# Fetched 121 repositories for user shonfeder
# Fetched 71 repositories for user yysun
# Fetched 164 repositories for user nickyiliwang
# Fetched 46 repositories for user melaniesigrid
# Fetched 149 repositories for user chyyran
# Fetched 979 repositories for user zoffixznet
# Fetched 336 repositories for user jrmuizel
# Fetched 19 repositories for user dipikabh
# Fetched 2 repositories for user farnoodma
# Fetched 9 repositories for user Hardanish-Singh
# Fetched 116 repositories for user rilian
# Fetched 58 repositories for user eltonvs
# Fetched 3 repositories for user brvoigt
# Fetched 55 repositories for user NS007-dev
# Fetched 118 repositories for user mstange
# Fetched 10 repositories for user adamfuhrer
# Fetched 17 repositories for user binyoon99
# Fetched 64 repositories for user invisibleBully
# Fetched 74 repositories for user thanethomson
# Fetched 31 repositories for user AVAV2500
# Fetched 8 repositories for user davifrossard
# Fetched 11 repositories for user blackHatMonkey
# Fetched 27 repositories for user nwjsmith
# Fetched 30 repositories for user junzhengca
# Fetched 104 repositories for user rafkhan
# Fetched 88 repositories for user rfratto
# Fetched 193 repositories for user shwina
# Fetched 209 repositories for user elliottsj
# Fetched 56 repositories for user NimaGhaedsharafi
# Fetched 101 repositories for user sumitarora
# Fetched 5 repositories for user seanpaultaylor
# Fetched 82 repositories for user probil
# Fetched 28 repositories for user bani
# Fetched 42 repositories for user liaojason2
# Fetched 25 repositories for user moein-shafi
# Fetched 13 repositories for user kyoshino
# Fetched 47 repositories for user scottclowe
# Fetched 32 repositories for user jinsley8
# Fetched 13 repositories for user caseware
# Fetched 104 repositories for user EmilyGraceSeville7cf
# Fetched 27 repositories for user amangalvedhekar
# Fetched 92 repositories for user Prtfw
# Fetched 4 repositories for user Shawn-Ogbomo
# Fetched 38 repositories for user haroldtreen
# Fetched 50 repositories for user liamks
# Fetched 0 repositories for user Jerry1211
# Fetched 54 repositories for user ianmackenzie
# Fetched 7 repositories for user ppaquette
# Fetched 92 repositories for user rymcol
# Fetched 6 repositories for user quepol
# Fetched 8 repositories for user nlalonde
# Fetched 58 repositories for user jstaf
# Fetched 138 repositories for user NickStrupat
# Fetched 49 repositories for user kiosion
# Fetched 110 repositories for user nickpresta
# Fetched 31 repositories for user ChigboIO
# Fetched 248 repositories for user radioblahaj
# Fetched 70 repositories for user dgomesbr
# Fetched 101 repositories for user douglasmakey
# Fetched 22 repositories for user eadamceylan
# Fetched 90 repositories for user thejmazz
# Fetched 249 repositories for user michaelchi08
# Fetched 53 repositories for user jameskeane
# Fetched 62 repositories for user svanoort
# Fetched 19 repositories for user hannes-brt
# Fetched 87 repositories for user FabioBatSilva
# Fetched 35 repositories for user KooroshRH
# Fetched 49 repositories for user LeNPaul
# Fetched 3 repositories for user hrzafer
# Fetched 49 repositories for user sepehrasgarian
# Fetched 59 repositories for user aehlke
# Fetched 0 repositories for user bgilham
# Fetched 51 repositories for user matt-sd-watson
# Fetched 48 repositories for user adamgoucher
# Fetched 15 repositories for user sauricat
# Fetched 34 repositories for user daniil
# Fetched 141 repositories for user ryanwilsonperkin
# Fetched 20 repositories for user prodseanb
# Fetched 81 repositories for user stevenvachon
# Fetched 124 repositories for user MisterJimson
# Fetched 45 repositories for user cltrudeau
# Fetched 71 repositories for user goatandsheep
# Fetched 25 repositories for user uptoamir
# Fetched 21 repositories for user WilliamPourmajidi
# Fetched 95 repositories for user NodeBB
# Fetched 78 repositories for user spacejack
# Fetched 49 repositories for user gvarandas
# Fetched 87 repositories for user lunaroyster
# Fetched 157 repositories for user HuakunShen
# Fetched 11 repositories for user vikramkakkar
# Fetched 35 repositories for user destruc7i0n
# Fetched 20 repositories for user ranacseruet
# Fetched 55 repositories for user scoremedia
# Fetched 39 repositories for user yusuf8ahmed
# Fetched 107 repositories for user yzgyyang
# Fetched 19 repositories for user SC4RECOIN
# Fetched 61 repositories for user gngdb
# Fetched 41 repositories for user samgermain
# Fetched 34 repositories for user itaymishan
# Fetched 12 repositories for user adrian-miasik
# Fetched 109 repositories for user jmcardon
# Fetched 395 repositories for user awgeezrick
# Fetched 29 repositories for user gregr
# Fetched 51 repositories for user HaydenMeloche
# Fetched 27 repositories for user clarabatt
# Fetched 41 repositories for user yasith
# Fetched 128 repositories for user robocoder
# Fetched 198 repositories for user amingilani
# Fetched 5 repositories for user igilitschenski
# Fetched 166 repositories for user AfzalivE
# Fetched 29 repositories for user zhangsu
# Fetched 25 repositories for user mabuyo
# Fetched 158 repositories for user mwarkentin
# Fetched 11 repositories for user rohithpudari
# Fetched 23 repositories for user UddamB
# Fetched 43 repositories for user osis
# Fetched 10 repositories for user yangze0930
# Fetched 30 repositories for user aarongough
# Fetched 83 repositories for user npjd
# Fetched 35 repositories for user itsbilal
# Fetched 6 repositories for user sharon-yi
# Fetched 35 repositories for user dcooney
# Fetched 80 repositories for user PabloVallejo
# Fetched 80 repositories for user mmonfared
# Fetched 2 repositories for user gmoledina
# Fetched 108 repositories for user mc256
# Fetched 46 repositories for user mlxd
# Fetched 44 repositories for user aravind-3105
# Fetched 123 repositories for user basil2style
# Fetched 77 repositories for user dellisd
# Fetched 35 repositories for user finiterank
# Fetched 9 repositories for user acode
# Fetched 44 repositories for user gorkem-cetin
# Fetched 43 repositories for user rwhogg
# Fetched 31 repositories for user andrewdamelio
# Fetched 62 repositories for user qasim
# Saved 60233 repositories to repositories.csv

# %%
import pandas as pd

# Load the repositories.csv file
repositories = pd.read_csv('repositories_unformat.csv')

# Columns that need conversion
columns_to_change = ['has_projects', 'has_wiki']

# Change 'True' to 'true' and 'False' to 'false' in specified columns
for column in columns_to_change:
    repositories[column] = repositories[column].replace({True: 'true', False: 'false'})

# Save the updated file
repositories.to_csv('repositories.csv', index=False)

print("Updated file saved as 'repositories.csv'")
# Out:
# Updated file saved as 'repositories_updated.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1
users = pd.read_csv('users.csv')
users.head()
# Out:
#           login            name   company         location  \
# 0      aneagoie  Andrei Neagoie       NaN  Toronto, Canada
# 1   ZhangMYihua     Yihua Zhang       NaN          Toronto
# 2   susanli2016        Susan Li       NaN   Toronto Canada
# 3  thedaviddias      David Dias  KIJIJICA  Toronto, Canada
# 4    ange-yaghi      Ange Yaghi       NaN          Toronto
#
#                    email  hireable  \
# 0                    NaN      True
# 1  yihuazhang2@gmail.com     False
# 2                    NaN     False
# 3                    NaN     False
# 4       me@angeyaghi.com     False
#
#                                                  bio  public_repos  followers  \
# 0  Senior Software Dev turned Instructor. Founder...           145      10279
# 1                         Toronto Software Developer           143       5801
# 2                               Chief Data Scientist            34       4921
# 3  💻 Passionate Front-End Dev & 🎨 UI/UX fan. Cont...            88       4546
# 4                                      C++ Developer            32       4023
#
#    following            created_at
# 0          1  2015-01-30T17:05:43Z
# 1         11  2015-01-18T00:01:02Z
# 2         68  2016-11-28T04:22:39Z
# 3        303  2010-04-05T14:40:12Z
# 4         11  2016-07-13T21:01:21Z

# %%
users['hireable'] = users['hireable'].fillna(False).astype(bool)

# %%
top5 = users.sort_values(by='followers', ascending=False).head()
print(','.join(top5['login'].tolist()))
# Out:
# aneagoie,ZhangMYihua,susanli2016,thedaviddias,ange-yaghi

# %%
# 2
users['created_at'] = pd.to_datetime(users['created_at'])

# %%
top_earliest = users.sort_values(by='created_at').head()
print(','.join(top_earliest['login'].tolist()))
# Out:
# jamesmacaulay,michaelklishin,myles,nwjsmith,vito

# %%
# 3
repos = pd.read_csv('repositories.csv')
repos.head()
# Out:
#       login                                        full_name  \
# 0  aneagoie                                 aneagoie/3D_roll
# 1  aneagoie  aneagoie/advanced-React-Redux-Training-Jeopardy
# 2  aneagoie         aneagoie/advanced-redux-training-RoboDex
# 3  aneagoie                         aneagoie/AirBnB-template
# 4  aneagoie                               aneagoie/ajaxCalls
#
#              created_at  stargazers_count  watchers_count    language  \
# 0  2017-01-08T20:05:27Z                 0               0  JavaScript
# 1  2017-01-31T20:34:22Z                 1               1         CSS
# 2  2017-01-25T15:05:15Z                 1               1  JavaScript
# 3  2015-06-19T18:00:33Z                 1               1        HTML
# 4  2015-06-11T14:22:59Z                 0               0  JavaScript
#
#    has_projects  has_wiki license_name
# 0          True      True          NaN
# 1          True      True          NaN
# 2          True      True          NaN
# 3          True      True          NaN
# 4          True      True          NaN

# %%
repos['license_name'].value_counts().head(3)
# Out:
# license_name
# mit           14797
# other          4790
# apache-2.0     4579
# Name: count, dtype: int64

# %%
# 4
users['company'].value_counts().head(1)
# Out:
# company
# UNIVERSITY OF TORONTO    21
# Name: count, dtype: int64

# %%
# 5
repos['language'].value_counts().head(1)
# Out:
# language
# JavaScript    11210
# Name: count, dtype: int64

# %%
# 6
users_after_2020 = users[users['created_at'] > '2020-01-01']
users_after_2020.head()
# Out:
#            login           name        company         location email  \
# 52    enderh3art     Jesse Zhou            NaN          Toronto   NaN
# 62    iceburgcrm    Iceburg CRM            NaN  Toronto, Canada   NaN
# 79   HamedBahram   Hamed Bahram      STUDIO-HB      Toronto, CA   NaN
# 94    scrumtuous  Darcy DeClute     SCRUMTUOUS      Toronto, ON   NaN
# 105    barry-far       bardiafa  MIZEGERD-TECH      Toronto, ON   NaN
#
#      hireable                                                bio  \
# 52      False                                                NaN
# 62      False                                        Iceburg CRM
# 79       True  Software developer & content creator from Cana...
# 94      False  I'm a certified Scrum Master and AWS Cloud Pra...
# 105     False  "Don't let negativity dim your light; use it a...
#
#      public_repos  followers  following                created_at
# 52              5        923          7 2020-04-28 05:36:17+00:00
# 62              5        714      19957 2022-11-11 21:59:06+00:00
# 79             87        578          3 2020-04-22 13:56:33+00:00
# 94             16        535         90 2021-12-17 18:56:47+00:00
# 105             5        490         10 2023-09-04 06:25:14+00:00

# %%
repos_2020 = repos[repos['login'].isin(users_after_2020['login'].tolist())]
repos_2020['language'].value_counts().head()
# Out:
# language
# JavaScript    338
# TypeScript    205
# Python        161
# HTML          122
# CSS            61
# Name: count, dtype: int64

# %%
# 7
avg_stars = repos.groupby('language')['stargazers_count'].mean()
top_lang = avg_stars.idxmax()
top_stars = avg_stars.max()
print(top_lang, top_stars)
# Out:
# Cython 1780.6666666666667

# %%
# 8
users['leader_strength'] = users['followers'] / (1 + users['following'])
top5_lead = users.sort_values(by='leader_strength', ascending=False).head()
print(','.join(top5_lead['login'].tolist()))
# Out:
# aneagoie,nayuki,GrapheneOS,hlissner,rspivak

# %%
# 9
correlation = users['followers'].corr(users['public_repos'])
correlation
# Out:
# 0.05547950303867636

# %%
# 10
import csv
followers = []
public_repos = []
with open('users.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        followers_count = int(row['followers'])
        public_repos_count = int(row['public_repos'])
        followers.append(followers_count)
        public_repos.append(public_repos_count)
if len(followers) > 1 and len(public_repos) > 1:
    slope, intercept = np.polyfit(public_repos, followers, 1)

    print(f"{slope:.3f}")
else:
    print("Error")
# Out:
# 0.253

# %%
# 11
if repos['has_projects'].dtype == 'object':
    repos['has_projects'] = repos['has_projects'].map({'true': True, 'false': False})
if repos['has_wiki'].dtype == 'object':
    repos['has_wiki'] = repos['has_wiki'].map({'true': True, 'false': False})

correlation = repos['has_projects'].corr(repos['has_wiki'])

print(round(correlation, 3))
# # Convert values if necessary
# repos['has_projects'] = repos['has_projects'].map({'true': True, 'false': False}).astype(bool)
# repos['has_wiki'] = repos['has_wiki'].map({'true': True, 'false': False}).astype(bool)

# # Drop any NaN values in these columns before correlation
# repos_filtered = repos[['has_projects', 'has_wiki']].dropna()

# # Calculate the correlation
# correlation = repos_filtered['has_projects'].corr(repos_filtered['has_wiki'])
# print(round(correlation, 3))
# Out:
# 0.353

# %%
# 12
# hireable_avg_following = users[users['hireable'] == True]['following'].mean()
# non_hireable_avg_following = users[users['hireable'] == False]['following'].mean()
# difference = hireable_avg_following - non_hireable_avg_following
# difference
# Calculate average following for hireable users
hireable_avg_following = users[users['hireable'] == True]['following'].mean()

# Calculate average following for non-hireable users (where hireable is not True or is blank)
non_hireable_avg_following = users[users['hireable'] != True]['following'].mean()

# Calculate the difference
difference = hireable_avg_following - non_hireable_avg_following

# Display the result rounded to 3 decimal places
round(difference, 3)
# Out:
# -13.382

# %%
# 13
from sklearn.linear_model import LinearRegression
users_with_bio = users[(users['bio'].notna()) & (users['bio'] != '')].copy()
users_with_bio.loc[:, 'bio_len'] = users_with_bio['bio'].str.len()

X = users_with_bio['bio_len'].values.reshape(-1,1)
y = users_with_bio['followers']

lr2 = LinearRegression()
lr2.fit(X, y)
lr2.coef_[0]
# Out:
# 1.4041986504876804

# %%
# 14
import csv
from collections import Counter
from datetime import datetime

weekend_repo_counts = Counter()

with open('repositories.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    for row in reader:
        created_at = row.get('created_at', '')
        if created_at:
            created_date = datetime.fromisoformat(created_at[:-1])

            if created_date.weekday() in [5, 6]:
                user_login = row['login']
                weekend_repo_counts[user_login] += 1

top_users = weekend_repo_counts.most_common(5)

top_logins = [user[0] for user in top_users]

print(','.join(top_logins))
# Out:
# n1ckfg,jsoref,QuinntyneBrown,invokethreatguy,andyw8

# %%
# 15
fraction_hierable = users[users['hireable'] == True]['email'].notna().mean()
fraction_non_hierable = users[users['hireable'] == False]['email'].notna().mean()
diff = fraction_hierable - fraction_non_hierable
diff
# Calculate the fraction of hireable users who have an email
# hireable_with_email = users[(users['hireable'] == True) & (users['email'].notna())].shape[0]
# total_hireable = users[users['hireable'] == True].shape[0]
# fraction_hireable = hireable_with_email / total_hireable if total_hireable > 0 else 0

# # Calculate the fraction of non-hireable users who have an email
# non_hireable_with_email = users[(users['hireable'] == False) & (users['email'].notna())].shape[0]
# total_non_hireable = users[users['hireable'] == False].shape[0]
# fraction_non_hireable = non_hireable_with_email / total_non_hireable if total_non_hireable > 0 else 0

# # Calculate the difference
# diff = fraction_hireable - fraction_non_hireable
# print("Difference in email fraction (hireable - non-hireable):", round(diff, 3))
# Out:
# 0.13476138828633405

# %%
# 16
new_users = users[users['name'].notna()].copy()
new_users['surname'] = new_users['name'].str.split().str[-1].str.strip()
surname_counts = new_users['surname'].value_counts()
max_count = surname_counts.max()
common_surnames = surname_counts[surname_counts == max_count].index.tolist()
common_surnames.sort()
print(','.join(common_surnames))
# Out:
# Ahmed
